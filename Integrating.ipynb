# %% [markdown]
# <center><img src="http://i.imgur.com/sSaOozN.png" width="500"></center>
#
# ## Course: Computational Thinking for Governance Analytics
#
# ### Prof. José Manuel Magallanes, PhD
# * Visiting Professor of Computational Policy at Evans School of Public Policy and Governance, and eScience Institute Senior Data Science Fellow, University of Washington.
# * Professor of Government and Political Methodology, Pontificia Universidad Católica del Perú.
#
# _____
#
# # Data Preprocessing in Python: Data Integration

# %% [markdown]
# Let's get some data first:

# %% [markdown]
# ## 1. The CIA data:

# %%
import pandas as pd

link1="https://www.cia.gov/library/publications/resources/the-world-factbook/fields/274.html"

cia=pd.read_html(link1,header=0,attrs={'id': 'fieldListing'})[0]

# %% [markdown]
# ### - Cleaning

# %%
# renaming both columns:
OldToNew={cia.columns[0]:'countries',cia.columns[1]:'co2'}
cia.rename(columns=OldToNew,inplace=True)

# cleaning Country (preventive)
cia.countries=cia.countries.str.strip()

# splitting second column, keeping main information. This overwrites co2.
result1=cia.co2.str.split(' Mt',expand=True)[0]
cia=cia.assign(co2=result1)

# extracting number and text from co2 into a dataframe, adding those to CIA
result2=cia.co2.str.extract('(?P<number>\d+\,*\.*\d*)\s*(?P<text>\D+)*')
cia=cia.assign(value=result2.number,
               unit=result2.text)

# deleting comma from newly created column'value'
cia.value=cia.value.str.replace(",","")

# recoding newly created column'unit':
replacements={'million': 10**6, "billion": 10**9,None:10**0}
cia.unit.replace(replacements,inplace=True)

# dropping unneeded column:
cia.drop(columns='co2',inplace=True)

# %% [markdown]
# ### - Formatting

# %%
# Formatting numeric columns:

# value is text, now to numeric type:
cia=cia.assign(value=pd.to_numeric(cia.value))

# once value and unit are numeric, 
# new column 'co2_in_MT' is created from multiplying both.
cia=cia.assign(co2_in_MT=cia.value*cia.unit)

# value and unit were temporary columns, they can go now.
cia.drop(columns=['value','unit'],inplace=True)

# %%
cia.head()
# Out:
#         countries    co2_in_MT
# 0     Afghanistan    9067000.0
# 1         Albania    4500000.0
# 2         Algeria  135900000.0
# 3  American Samoa     361100.0
# 4          Angola   20950000.0

# %%
cia.dtypes
# Out:
# countries     object
# co2_in_MT    float64
# dtype: object

# %% [markdown]
# ## 2. The DEMOCRACY INDEX data:

# %%
import pandas as pd
link2= "https://en.wikipedia.org/wiki/Democracy_Index" 

# getting the data frame in one step:
demodex=pd.read_html(link2,header=0,flavor='bs4',attrs={'class': 'wikitable sortable'})[0]

# %% [markdown]
# ### - Cleaning

# %%
#bye row 167, and Rank
demodex=demodex.drop(index=167,columns=['Rank'])

# Simplifying column names to facilitate further work:
demodex.columns=demodex.columns.str.replace('\s+',"")

# preventive cleaning of numeric cell values:
NumericColNames=demodex.iloc[:,2:7].columns
badSymbols=[]
for columnName in NumericColNames:
    for cell in demodex[columnName]:
        try:
            float(cell)
        except:
            if cell not in badSymbols:
                badSymbols.append(cell)
            
import numpy as np  
demodex.loc[:,NumericColNames].replace(to_replace=badSymbols,value=np.nan,inplace=True)

# see if we have some strange value in the categorical columns:
demodex.iloc[:,-2::].apply(set).to_list()
# Out:
# [{'Authoritarian', 'Flawed democracy', 'Full democracy', 'Hybrid regime'},
#  {'Africa',
#   'Asia',
#   'Europe',
#   'Europe/Asia',
#   'North America',
#   'Oceania',
#   'South America'}]

# %% [markdown]
# ### - Formatting

# %%
# Formatting numeric columns

# save column names of the columns to change:
colsToChange=demodex.iloc[:,2:7].columns
# make changes NOT using iloc:
demodex[colsToChange]=demodex[colsToChange].apply(pd.to_numeric)


# Formatting categorical columns
# NOMINAL
demodex.Continent=pd.Categorical(demodex.Continent)
# ORDINAL
#rewrite the levels in order:
correctLevels=['Authoritarian', 'Hybrid regime', 'Flawed democracy','Full democracy']
demodex.Regimetype=pd.Categorical(demodex.Regimetype,categories=correctLevels,ordered=True)

# %%
demodex.dtypes
# Out:
# Country                           object
# Score                             object
# Electoralprocessandpluralism     float64
# Functioningofgovernment          float64
# Politicalparticipation           float64
# Politicalculture                 float64
# Civilliberties                   float64
# Regimetype                      category
# Continent                       category
# dtype: object

# %%
demodex.Continent.cat.ordered
# Out:
# False

# %%
demodex.Regimetype.cat.ordered
# Out:
# True

# %% [markdown]
# ## 3. The HUMAN DEVELOPMENT INDEX data:

# %% [markdown]
# * Go to this [website](http://hdr.undp.org/en/content/table-1-human-development-index-and-its-components-1) and download the CSV file about Human Develeopment Index and its components.
# * Go to your gmail account and create a new GoogleSheet.
# * Import the file into the GoogleSheet.
# * Make sure commas do not appear in thousands.
# * Create a CSV link to that data from Google.
# * Clean and format the data

# %%
link1="https://docs.google.com/spreadsheets/d/e/2PACX-1vSNMpr1Dz3tvMqEAnmGAjaQi19zcsEiLZQn6f5ZM6ap4tzNy6bQUXtctNebCL4OyEN6UODUc0U7B9pf/pub?gid=1506000439&single=true&output=csv"

# %%
yourLink="https://docs.google.com/spreadsheets/d/e/2PACX-1vRZBSLXN-Uh_sOG-n25e8pGao1FCfLpNyWU4WtUD18fxxRzy5FnB-0PgRQYGcu7ZZCeLF8Y0lzA_2ql/pub?gid=1426880746&single=true&output=csv"

# %% [markdown]
# Collecting the data with the link from Google:

# %%
# need to call pandas:

import pandas as pd

hdi=pd.read_csv(yourLink)

# %% [markdown]
# ### -  Cleaning

# %% [markdown]
# Keep only data for data frame

# %% [markdown]
# #### * Check first rows

# %%
# Is the header in the right place:
hdi.head(10)
# Out:
#   Unnamed: 0 Table 1. Human Development Index and its components   \
# 0        NaN                                                NaN
# 1        NaN                                                NaN
# 2        NaN                                                NaN
# 3        NaN                                                NaN
# 4   HDI rank                                            Country
# 5        NaN                                                NaN
# 6        NaN                        VERY HIGH HUMAN DEVELOPMENT
# 7          1                                             Norway
# 8          2                                        Switzerland
# 9          3                                            Ireland
#
#                        Unnamed: 2  Unnamed: 3                Unnamed: 4  \
# 0                             NaN         NaN                       NaN
# 1                             NaN         NaN                      SDG3
# 2                             NaN         NaN                       NaN
# 3  Human development index (HDI)          NaN  Life expectancy at birth
# 4                   (index value)         NaN                   (years)
# 5                            2018         NaN                      2018
# 6                             NaN         NaN                       NaN
# 7                           0.954         NaN                      82.3
# 8                           0.946         NaN                      83.6
# 9                           0.942         NaN                      82.1
#
#   Unnamed: 5                   Unnamed: 6 Unnamed: 7               Unnamed: 8  \
# 0        NaN                          NaN        NaN                      NaN
# 1        NaN                       SDG4.3        NaN                   SDG4.6
# 2        NaN                          NaN        NaN                      NaN
# 3        NaN  Expected years of schooling        NaN  Mean years of schooling
# 4        NaN                      (years)        NaN                  (years)
# 5        NaN                         2018          a                     2018
# 6        NaN                          NaN        NaN                      NaN
# 7        NaN                         18.1          b                     12.6
# 8        NaN                         16.2        NaN                     13.4
# 9        NaN                         18.8          b                     12.5
#
#   Unnamed: 9                             Unnamed: 10 Unnamed: 11  \
# 0        NaN                                     NaN         NaN
# 1        NaN                                  SDG8.5         NaN
# 2        NaN                                     NaN         NaN
# 3        NaN  Gross national income (GNI) per capita         NaN
# 4        NaN                            (2011 PPP $)         NaN
# 5          a                                 2018.00         NaN
# 6        NaN                                     NaN         NaN
# 7        NaN                                68058.62         NaN
# 8        NaN                                59374.73         NaN
# 9          c                                55659.68         NaN
#
#                           Unnamed: 12  Unnamed: 13 Unnamed: 14
# 0                                 NaN          NaN         NaN
# 1                                 NaN          NaN         NaN
# 2                                 NaN          NaN         NaN
# 3  GNI per capita rank minus HDI rank          NaN    HDI rank
# 4                                 NaN          NaN         NaN
# 5                                2018          NaN        2017
# 6                                 NaN          NaN         NaN
# 7                                   5          NaN           1
# 8                                   8          NaN           2
# 9                                   9          NaN           3

# %% [markdown]
# Two problems:
#
# * The headers are in two different rows.
# * The data starts in below zero.
#
# Cleaning the top part:
#
# * Saving the headers:

# %%
# for the first two columns:
hdi.iloc[4,:2].tolist()
# Out:
# ['HDI rank', 'Country']

# %%
# for the rest of columns columns:
hdi.iloc[3,2:].tolist()
# Out:
# ['Human development index (HDI) ',
#  nan,
#  'Life expectancy at birth',
#  nan,
#  'Expected years of schooling',
#  nan,
#  'Mean years of schooling',
#  nan,
#  'Gross national income (GNI) per capita',
#  nan,
#  'GNI per capita rank minus HDI rank',
#  nan,
#  'HDI rank']

# %%
# saving headers:
CurrentHeaders=hdi.iloc[4,:2].tolist()+hdi.iloc[3,2:].tolist()

# you saved this:
CurrentHeaders
# Out:
# ['HDI rank',
#  'Country',
#  'Human development index (HDI) ',
#  nan,
#  'Life expectancy at birth',
#  nan,
#  'Expected years of schooling',
#  nan,
#  'Mean years of schooling',
#  nan,
#  'Gross national income (GNI) per capita',
#  nan,
#  'GNI per capita rank minus HDI rank',
#  nan,
#  'HDI rank']

# %% [markdown]
# * Setting the begining of data:
#
# We need to get rid the top rows that are not part of the data frame:

# %%
# PREVIEW: deleting rows, NORWAY should be the first row:
hdi.drop(index=range(0,7)) #7 in range() will not be erased.
# Out:
#     Unnamed: 0 Table 1. Human Development Index and its components   \
# 7            1                                             Norway
# 8            2                                        Switzerland
# 9            3                                            Ireland
# 10           4                                            Germany
# 11           4                             Hong Kong, China (SAR)
# ..         ...                                                ...
# 264        NaN                         Column 2: UNDESA (2019b).
# 265        NaN  Column 3: UNESCO Institute for Statistics (201...
# 266        NaN  Column 4: UNESCO Institute for Statistics (201...
# 267        NaN  Column 5: World Bank (2019a), IMF (2019) and U...
# 268        NaN  Column 6: Calculated based on data in columns ...
#
#     Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 7        0.954         NaN       82.3        NaN       18.1          b
# 8        0.946         NaN       83.6        NaN       16.2        NaN
# 9        0.942         NaN       82.1        NaN       18.8          b
# 10       0.939         NaN       81.2        NaN       17.1        NaN
# 11       0.939         NaN       84.7        NaN       16.5        NaN
# ..         ...         ...        ...        ...        ...        ...
# 264        NaN         NaN        NaN        NaN        NaN        NaN
# 265        NaN         NaN        NaN        NaN        NaN        NaN
# 266        NaN         NaN        NaN        NaN        NaN        NaN
# 267        NaN         NaN        NaN        NaN        NaN        NaN
# 268        NaN         NaN        NaN        NaN        NaN        NaN
#
#     Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  Unnamed: 13  \
# 7         12.6        NaN    68058.62         NaN           5          NaN
# 8         13.4        NaN    59374.73         NaN           8          NaN
# 9         12.5          c    55659.68         NaN           9          NaN
# 10        14.1        NaN    46945.95         NaN          15          NaN
# 11        12.0        NaN    60220.80         NaN           5          NaN
# ..         ...        ...         ...         ...         ...          ...
# 264        NaN        NaN         NaN         NaN         NaN          NaN
# 265        NaN        NaN         NaN         NaN         NaN          NaN
# 266        NaN        NaN         NaN         NaN         NaN          NaN
# 267        NaN        NaN         NaN         NaN         NaN          NaN
# 268        NaN        NaN         NaN         NaN         NaN          NaN
#
#     Unnamed: 14
# 7             1
# 8             2
# 9             3
# 10            4
# 11            6
# ..          ...
# 264         NaN
# 265         NaN
# 266         NaN
# 267         NaN
# 268         NaN
#
# [262 rows x 15 columns]

# %% [markdown]
# Making effective the last code:

# %%
hdi.drop(index=range(0,7),inplace=True)

# %% [markdown]
# As soon as you delete rows, you should reset the indexes:

# %%
hdi.reset_index(drop=True,inplace=True)

# %% [markdown]
# You can rename the columns now:

# %%
# rename columns
hdi.columns=CurrentHeaders

# %% [markdown]
# So far:

# %%
hdi.head()
# Out:
#   HDI rank                 Country Human development index (HDI)   NaN  \
# 0        1                  Norway                          0.954  NaN
# 1        2             Switzerland                          0.946  NaN
# 2        3                 Ireland                          0.942  NaN
# 3        4                 Germany                          0.939  NaN
# 4        4  Hong Kong, China (SAR)                          0.939  NaN
#
#   Life expectancy at birth  NaN Expected years of schooling  NaN  \
# 0                     82.3  NaN                        18.1    b
# 1                     83.6  NaN                        16.2  NaN
# 2                     82.1  NaN                        18.8    b
# 3                     81.2  NaN                        17.1  NaN
# 4                     84.7  NaN                        16.5  NaN
#
#   Mean years of schooling  NaN Gross national income (GNI) per capita  NaN  \
# 0                    12.6  NaN                               68058.62  NaN
# 1                    13.4  NaN                               59374.73  NaN
# 2                    12.5    c                               55659.68  NaN
# 3                    14.1  NaN                               46945.95  NaN
# 4                    12.0  NaN                               60220.80  NaN
#
#   GNI per capita rank minus HDI rank  NaN HDI rank
# 0                                  5  NaN        1
# 1                                  8  NaN        2
# 2                                  9  NaN        3
# 3                                 15  NaN        4
# 4                                  5  NaN        6

# %% [markdown]
# #### * Check last rows

# %%
hdi.tail(65) #change until you see last data row
# Out:
#     HDI rank                                            Country  \
# 197       ..                                            Somalia
# 198       ..                                             Tuvalu
# 199      NaN                                                NaN
# 200      NaN                           Human development groups
# 201      NaN                        Very high human development
# ..       ...                                                ...
# 257      NaN                         Column 2: UNDESA (2019b).
# 258      NaN  Column 3: UNESCO Institute for Statistics (201...
# 259      NaN  Column 4: UNESCO Institute for Statistics (201...
# 260      NaN  Column 5: World Bank (2019a), IMF (2019) and U...
# 261      NaN  Column 6: Calculated based on data in columns ...
#
#     Human development index (HDI)   NaN Life expectancy at birth  NaN  \
# 197                             ..  NaN                     57.1  NaN
# 198                             ..  NaN                       ..  NaN
# 199                            NaN  NaN                      NaN  NaN
# 200                            NaN  NaN                      NaN  NaN
# 201                          0.892  NaN                     79.5  NaN
# ..                             ...  ...                      ...  ...
# 257                            NaN  NaN                      NaN  NaN
# 258                            NaN  NaN                      NaN  NaN
# 259                            NaN  NaN                      NaN  NaN
# 260                            NaN  NaN                      NaN  NaN
# 261                            NaN  NaN                      NaN  NaN
#
#     Expected years of schooling  NaN Mean years of schooling  NaN  \
# 197                          ..  NaN                      ..  NaN
# 198                        12.3  NaN                      ..  NaN
# 199                         NaN  NaN                     NaN  NaN
# 200                         NaN  NaN                     NaN  NaN
# 201                        16.4  NaN                    12.0  NaN
# ..                          ...  ...                     ...  ...
# 257                         NaN  NaN                     NaN  NaN
# 258                         NaN  NaN                     NaN  NaN
# 259                         NaN  NaN                     NaN  NaN
# 260                         NaN  NaN                     NaN  NaN
# 261                         NaN  NaN                     NaN  NaN
#
#     Gross national income (GNI) per capita  NaN  \
# 197                                     ..  NaN
# 198                                5408.95  NaN
# 199                                    NaN  NaN
# 200                                    NaN  NaN
# 201                               40111.57  NaN
# ..                                     ...  ...
# 257                                    NaN  NaN
# 258                                    NaN  NaN
# 259                                    NaN  NaN
# 260                                    NaN  NaN
# 261                                    NaN  NaN
#
#     GNI per capita rank minus HDI rank  NaN HDI rank
# 197                                 ..  NaN       ..
# 198                                 ..  NaN       ..
# 199                                NaN  NaN      NaN
# 200                                NaN  NaN      NaN
# 201                                  —  NaN        —
# ..                                 ...  ...      ...
# 257                                NaN  NaN      NaN
# 258                                NaN  NaN      NaN
# 259                                NaN  NaN      NaN
# 260                                NaN  NaN      NaN
# 261                                NaN  NaN      NaN
#
# [65 rows x 15 columns]

# %% [markdown]
# Based on what is diSplayed, you should keep data up to Tuvalu country:

# %%
# deleting: preview
hdi.drop(index=range(199,262)) # rows starting from 199 will be erased
# Out:
#     HDI rank                 Country Human development index (HDI)   NaN  \
# 0          1                  Norway                          0.954  NaN
# 1          2             Switzerland                          0.946  NaN
# 2          3                 Ireland                          0.942  NaN
# 3          4                 Germany                          0.939  NaN
# 4          4  Hong Kong, China (SAR)                          0.939  NaN
# ..       ...                     ...                            ...  ...
# 194       ..                  Monaco                             ..  NaN
# 195       ..                   Nauru                             ..  NaN
# 196       ..              San Marino                             ..  NaN
# 197       ..                 Somalia                             ..  NaN
# 198       ..                  Tuvalu                             ..  NaN
#
#     Life expectancy at birth  NaN Expected years of schooling  NaN  \
# 0                       82.3  NaN                        18.1    b
# 1                       83.6  NaN                        16.2  NaN
# 2                       82.1  NaN                        18.8    b
# 3                       81.2  NaN                        17.1  NaN
# 4                       84.7  NaN                        16.5  NaN
# ..                       ...  ...                         ...  ...
# 194                       ..  NaN                          ..  NaN
# 195                       ..  NaN                        11.3    e
# 196                       ..  NaN                        15.1  NaN
# 197                     57.1  NaN                          ..  NaN
# 198                       ..  NaN                        12.3  NaN
#
#     Mean years of schooling  NaN Gross national income (GNI) per capita  NaN  \
# 0                      12.6  NaN                               68058.62  NaN
# 1                      13.4  NaN                               59374.73  NaN
# 2                      12.5    c                               55659.68  NaN
# 3                      14.1  NaN                               46945.95  NaN
# 4                      12.0  NaN                               60220.80  NaN
# ..                      ...  ...                                    ...  ...
# 194                      ..  NaN                                     ..  NaN
# 195                      ..  NaN                               17312.59  NaN
# 196                      ..  NaN                                     ..  NaN
# 197                      ..  NaN                                     ..  NaN
# 198                      ..  NaN                                5408.95  NaN
#
#     GNI per capita rank minus HDI rank  NaN HDI rank
# 0                                    5  NaN        1
# 1                                    8  NaN        2
# 2                                    9  NaN        3
# 3                                   15  NaN        4
# 4                                    5  NaN        6
# ..                                 ...  ...      ...
# 194                                 ..  NaN       ..
# 195                                 ..  NaN       ..
# 196                                 ..  NaN       ..
# 197                                 ..  NaN       ..
# 198                                 ..  NaN       ..
#
# [199 rows x 15 columns]

# %% [markdown]
# Making effective the last code:

# %%
hdi.drop(index=range(199,262),inplace=True) # should I reset indexes?

# %% [markdown]
# So far:

# %%
hdi
# Out:
#     HDI rank                 Country Human development index (HDI)   NaN  \
# 0          1                  Norway                          0.954  NaN
# 1          2             Switzerland                          0.946  NaN
# 2          3                 Ireland                          0.942  NaN
# 3          4                 Germany                          0.939  NaN
# 4          4  Hong Kong, China (SAR)                          0.939  NaN
# ..       ...                     ...                            ...  ...
# 194       ..                  Monaco                             ..  NaN
# 195       ..                   Nauru                             ..  NaN
# 196       ..              San Marino                             ..  NaN
# 197       ..                 Somalia                             ..  NaN
# 198       ..                  Tuvalu                             ..  NaN
#
#     Life expectancy at birth  NaN Expected years of schooling  NaN  \
# 0                       82.3  NaN                        18.1    b
# 1                       83.6  NaN                        16.2  NaN
# 2                       82.1  NaN                        18.8    b
# 3                       81.2  NaN                        17.1  NaN
# 4                       84.7  NaN                        16.5  NaN
# ..                       ...  ...                         ...  ...
# 194                       ..  NaN                          ..  NaN
# 195                       ..  NaN                        11.3    e
# 196                       ..  NaN                        15.1  NaN
# 197                     57.1  NaN                          ..  NaN
# 198                       ..  NaN                        12.3  NaN
#
#     Mean years of schooling  NaN Gross national income (GNI) per capita  NaN  \
# 0                      12.6  NaN                               68058.62  NaN
# 1                      13.4  NaN                               59374.73  NaN
# 2                      12.5    c                               55659.68  NaN
# 3                      14.1  NaN                               46945.95  NaN
# 4                      12.0  NaN                               60220.80  NaN
# ..                      ...  ...                                    ...  ...
# 194                      ..  NaN                                     ..  NaN
# 195                      ..  NaN                               17312.59  NaN
# 196                      ..  NaN                                     ..  NaN
# 197                      ..  NaN                                     ..  NaN
# 198                      ..  NaN                                5408.95  NaN
#
#     GNI per capita rank minus HDI rank  NaN HDI rank
# 0                                    5  NaN        1
# 1                                    8  NaN        2
# 2                                    9  NaN        3
# 3                                   15  NaN        4
# 4                                    5  NaN        6
# ..                                 ...  ...      ...
# 194                                 ..  NaN       ..
# 195                                 ..  NaN       ..
# 196                                 ..  NaN       ..
# 197                                 ..  NaN       ..
# 198                                 ..  NaN       ..
#
# [199 rows x 15 columns]

# %% [markdown]
# #### * Check the column names

# %% [markdown]
# You have columns with names "missing", you want to avoid those:

# %%
# Get good columns

GoodHeaders=[header for header in CurrentHeaders if str(header) != 'nan']
#
GoodHeaders
# Out:
# ['HDI rank',
#  'Country',
#  'Human development index (HDI) ',
#  'Life expectancy at birth',
#  'Expected years of schooling',
#  'Mean years of schooling',
#  'Gross national income (GNI) per capita',
#  'GNI per capita rank minus HDI rank',
#  'HDI rank']

# %% [markdown]
# The column **HDI rank** appears twice, because it appears twice in the data. Also, you have another rank **GNI per capita rank minus HDI rank'**. Ranks are repetitive because we have the scores. So, you can always get rid of them in this and other similar situations:

# %%
FinalHeaders=[h for h in GoodHeaders if 'rank' not in h]
# then
FinalHeaders
# Out:
# ['Country',
#  'Human development index (HDI) ',
#  'Life expectancy at birth',
#  'Expected years of schooling',
#  'Mean years of schooling',
#  'Gross national income (GNI) per capita']

# %%
# remember loc works with names, not with positions:

hdi.loc[:,FinalHeaders]
# Out:
#                     Country Human development index (HDI)   \
# 0                    Norway                          0.954
# 1               Switzerland                          0.946
# 2                   Ireland                          0.942
# 3                   Germany                          0.939
# 4    Hong Kong, China (SAR)                          0.939
# ..                      ...                            ...
# 194                  Monaco                             ..
# 195                   Nauru                             ..
# 196              San Marino                             ..
# 197                 Somalia                             ..
# 198                  Tuvalu                             ..
#
#     Life expectancy at birth Expected years of schooling  \
# 0                       82.3                        18.1
# 1                       83.6                        16.2
# 2                       82.1                        18.8
# 3                       81.2                        17.1
# 4                       84.7                        16.5
# ..                       ...                         ...
# 194                       ..                          ..
# 195                       ..                        11.3
# 196                       ..                        15.1
# 197                     57.1                          ..
# 198                       ..                        12.3
#
#     Mean years of schooling Gross national income (GNI) per capita
# 0                      12.6                               68058.62
# 1                      13.4                               59374.73
# 2                      12.5                               55659.68
# 3                      14.1                               46945.95
# 4                      12.0                               60220.80
# ..                      ...                                    ...
# 194                      ..                                     ..
# 195                      ..                               17312.59
# 196                      ..                                     ..
# 197                      ..                                     ..
# 198                      ..                                5408.95
#
# [199 rows x 6 columns]

# %% [markdown]
# Saving previous result:

# %%
hdi=hdi.loc[:,FinalHeaders]

# %%
# you have:
hdi.head()
# Out:
#                   Country Human development index (HDI)   \
# 0                  Norway                          0.954
# 1             Switzerland                          0.946
# 2                 Ireland                          0.942
# 3                 Germany                          0.939
# 4  Hong Kong, China (SAR)                          0.939
#
#   Life expectancy at birth Expected years of schooling  \
# 0                     82.3                        18.1
# 1                     83.6                        16.2
# 2                     82.1                        18.8
# 3                     81.2                        17.1
# 4                     84.7                        16.5
#
#   Mean years of schooling Gross national income (GNI) per capita
# 0                    12.6                               68058.62
# 1                    13.4                               59374.73
# 2                    12.5                               55659.68
# 3                    14.1                               46945.95
# 4                    12.0                               60220.80

# %% [markdown]
# The remaining column names need to improve:

# %%
# replace with '' (empty) the "blanks":
hdi.columns.str.replace("\s","")
# Out:
# Index(['Country', 'Humandevelopmentindex(HDI)', 'Lifeexpectancyatbirth',
#        'Expectedyearsofschooling', 'Meanyearsofschooling',
#        'Grossnationalincome(GNI)percapita'],
#       dtype='object')

# %%
# replace with '' (empty) consecutive word characters in parenthesis:
hdi.columns.str.replace("\(\w+\)","")
# Out:
# Index(['Country', 'Human development index  ', 'Life expectancy at birth',
#        'Expected years of schooling', 'Mean years of schooling',
#        'Gross national income  per capita'],
#       dtype='object')

# %%
#or all combines
hdi.columns.str.replace("\s+|\(\w+\)","")
# Out:
# Index(['Country', 'Humandevelopmentindex', 'Lifeexpectancyatbirth',
#        'Expectedyearsofschooling', 'Meanyearsofschooling',
#        'Grossnationalincomepercapita'],
#       dtype='object')

# %% [markdown]
# Saving result:

# %%
hdi.columns=hdi.columns.str.replace("\s+|\(\w+\)","")

# %%
hdi.head()
# Out:
#                   Country Humandevelopmentindex Lifeexpectancyatbirth  \
# 0                  Norway                 0.954                  82.3
# 1             Switzerland                 0.946                  83.6
# 2                 Ireland                 0.942                  82.1
# 3                 Germany                 0.939                  81.2
# 4  Hong Kong, China (SAR)                 0.939                  84.7
#
#   Expectedyearsofschooling Meanyearsofschooling Grossnationalincomepercapita
# 0                     18.1                 12.6                     68058.62
# 1                     16.2                 13.4                     59374.73
# 2                     18.8                 12.5                     55659.68
# 3                     17.1                 14.1                     46945.95
# 4                     16.5                 12.0                     60220.80

# %% [markdown]
# #### * Check the cell values

# %% [markdown]
# Find cells where all numeric data is missing, that is, a country with no data:

# %%
# check empty cells from second to last
#hdi.iloc[:,1:]
hdi[hdi.iloc[:,1:].isnull().all(axis=1)] #ALL
# Out:
#                             Country Humandevelopmentindex  \
# 62           HIGH HUMAN DEVELOPMENT                   NaN
# 117        MEDIUM HUMAN DEVELOPMENT                   NaN
# 155           LOW HUMAN DEVELOPMENT                   NaN
# 192  OTHER COUNTRIES OR TERRITORIES                   NaN
#
#     Lifeexpectancyatbirth Expectedyearsofschooling Meanyearsofschooling  \
# 62                    NaN                      NaN                  NaN
# 117                   NaN                      NaN                  NaN
# 155                   NaN                      NaN                  NaN
# 192                   NaN                      NaN                  NaN
#
#     Grossnationalincomepercapita
# 62                           NaN
# 117                          NaN
# 155                          NaN
# 192                          NaN

# %% [markdown]
# These are no countries. They were subtitles for groups of countries.

# %% [markdown]
# You need the opposite to that:

# %%
# the opposite
hdi[hdi.iloc[:,1:].notnull().all(axis=1)]
# Out:
#                     Country Humandevelopmentindex Lifeexpectancyatbirth  \
# 0                    Norway                 0.954                  82.3
# 1               Switzerland                 0.946                  83.6
# 2                   Ireland                 0.942                  82.1
# 3                   Germany                 0.939                  81.2
# 4    Hong Kong, China (SAR)                 0.939                  84.7
# ..                      ...                   ...                   ...
# 194                  Monaco                    ..                    ..
# 195                   Nauru                    ..                    ..
# 196              San Marino                    ..                    ..
# 197                 Somalia                    ..                  57.1
# 198                  Tuvalu                    ..                    ..
#
#     Expectedyearsofschooling Meanyearsofschooling Grossnationalincomepercapita
# 0                       18.1                 12.6                     68058.62
# 1                       16.2                 13.4                     59374.73
# 2                       18.8                 12.5                     55659.68
# 3                       17.1                 14.1                     46945.95
# 4                       16.5                 12.0                     60220.80
# ..                       ...                  ...                          ...
# 194                       ..                   ..                           ..
# 195                     11.3                   ..                     17312.59
# 196                     15.1                   ..                           ..
# 197                       ..                   ..                           ..
# 198                     12.3                   ..                      5408.95
#
# [195 rows x 6 columns]

# %% [markdown]
# Keepin what you need:

# %%
hdi=hdi[hdi.iloc[:,1:].notnull().all(axis=1)]

# %% [markdown]
# The last code deleted rows, then indexes need to be reset:

# %%
hdi.reset_index(drop=True, inplace=True)

# %% [markdown]
# So far:

# %%
hdi
# Out:
#                     Country Humandevelopmentindex Lifeexpectancyatbirth  \
# 0                    Norway                 0.954                  82.3
# 1               Switzerland                 0.946                  83.6
# 2                   Ireland                 0.942                  82.1
# 3                   Germany                 0.939                  81.2
# 4    Hong Kong, China (SAR)                 0.939                  84.7
# ..                      ...                   ...                   ...
# 190                  Monaco                    ..                    ..
# 191                   Nauru                    ..                    ..
# 192              San Marino                    ..                    ..
# 193                 Somalia                    ..                  57.1
# 194                  Tuvalu                    ..                    ..
#
#     Expectedyearsofschooling Meanyearsofschooling Grossnationalincomepercapita
# 0                       18.1                 12.6                     68058.62
# 1                       16.2                 13.4                     59374.73
# 2                       18.8                 12.5                     55659.68
# 3                       17.1                 14.1                     46945.95
# 4                       16.5                 12.0                     60220.80
# ..                       ...                  ...                          ...
# 190                       ..                   ..                           ..
# 191                     11.3                   ..                     17312.59
# 192                     15.1                   ..                           ..
# 193                       ..                   ..                           ..
# 194                     12.3                   ..                      5408.95
#
# [195 rows x 6 columns]

# %% [markdown]
# #### * Check the cell values

# %% [markdown]
# Above you see some characters that are not numbers, are they missing values:

# %%
hdi[hdi.iloc[:,1:].isnull().any(axis=1)] #ANY
# Out:
# Empty DataFrame
# Columns: [Country, Humandevelopmentindex, Lifeexpectancyatbirth, Expectedyearsofschooling, Meanyearsofschooling, Grossnationalincomepercapita]
# Index: []

# %% [markdown]
# There are symbols that represent missing values, but they are not recognized so. We need to check what values in those **numeric** columns are not numbers:

# %%
badHDISymbols=[] # list for bad symbols

NumericColNames=hdi.iloc[:,1:].columns # save names of columns with numeric data

for columnName in NumericColNames:# visit every column name
    for cell in hdi[columnName]:# visit every cell for that column
        try:
            float(cell) # try this
        except: # if not possible:            
            if cell not in badHDISymbols:# if cell is not in the list                
                badHDISymbols.append(cell)# add it to the list

# you get:
badHDISymbols
# Out:
# ['..']

# %% [markdown]
# You need to replace that value in the numeric columns:

# %%
import numpy as np

hdi.replace(to_replace=badHDISymbols,value=np.nan,inplace=True)

# %%
# you have:
hdi
# Out:
#                     Country Humandevelopmentindex Lifeexpectancyatbirth  \
# 0                    Norway                 0.954                  82.3
# 1               Switzerland                 0.946                  83.6
# 2                   Ireland                 0.942                  82.1
# 3                   Germany                 0.939                  81.2
# 4    Hong Kong, China (SAR)                 0.939                  84.7
# ..                      ...                   ...                   ...
# 190                  Monaco                   NaN                   NaN
# 191                   Nauru                   NaN                   NaN
# 192              San Marino                   NaN                   NaN
# 193                 Somalia                   NaN                  57.1
# 194                  Tuvalu                   NaN                   NaN
#
#     Expectedyearsofschooling Meanyearsofschooling Grossnationalincomepercapita
# 0                       18.1                 12.6                     68058.62
# 1                       16.2                 13.4                     59374.73
# 2                       18.8                 12.5                     55659.68
# 3                       17.1                 14.1                     46945.95
# 4                       16.5                 12.0                     60220.80
# ..                       ...                  ...                          ...
# 190                      NaN                  NaN                          NaN
# 191                     11.3                  NaN                     17312.59
# 192                     15.1                  NaN                          NaN
# 193                      NaN                  NaN                          NaN
# 194                     12.3                  NaN                      5408.95
#
# [195 rows x 6 columns]

# %% [markdown]
# When you have numbers in your columns, you can request statistical summaries:

# %%
hdi.describe(include='all')
# Out:
#        Country Humandevelopmentindex Lifeexpectancyatbirth  \
# count      195                   189                   191
# unique     195                   153                   132
# top      Egypt                 0.724                  82.1
# freq         1                     4                     5
#
#        Expectedyearsofschooling Meanyearsofschooling  \
# count                       193                  189
# unique                       93                   89
# top                        12.7                  9.7
# freq                          6                    6
#
#        Grossnationalincomepercapita
# count                           191
# unique                          191
# top                        56140.23
# freq                              1

# %% [markdown]
# You are not getting those because they lack format.

# %% [markdown]
# ### -  Formatting

# %% [markdown]
# Check the data types:

# %%
hdi.dtypes
# Out:
# Country                         object
# Humandevelopmentindex           object
# Lifeexpectancyatbirth           object
# Expectedyearsofschooling        object
# Meanyearsofschooling            object
# Grossnationalincomepercapita    object
# dtype: object

# %% [markdown]
# Country can remain as an object (text), but not the rest.

# %% [markdown]
# * **Formatting into numeric type**:

# %%
# as easy as:

hdi[NumericColNames]=hdi.loc[:,NumericColNames].apply(pd.to_numeric)

# %%
#recheck
hdi.dtypes
# Out:
# Country                          object
# Humandevelopmentindex           float64
# Lifeexpectancyatbirth           float64
# Expectedyearsofschooling        float64
# Meanyearsofschooling            float64
# Grossnationalincomepercapita    float64
# dtype: object

# %%
# recheck
hdi.describe(include='all')
# Out:
#        Country  Humandevelopmentindex  Lifeexpectancyatbirth  \
# count      195             189.000000             191.000000
# unique     195                    NaN                    NaN
# top      Egypt                    NaN                    NaN
# freq         1                    NaN                    NaN
# mean       NaN               0.713450              72.417277
# std        NaN               0.150795               7.508442
# min        NaN               0.377000              52.800000
# 25%        NaN               0.596000              67.200000
# 50%        NaN               0.728000              73.800000
# 75%        NaN               0.830000              77.700000
# max        NaN               0.954000              84.700000
#
#         Expectedyearsofschooling  Meanyearsofschooling  \
# count                 193.000000            189.000000
# unique                       NaN                   NaN
# top                          NaN                   NaN
# freq                         NaN                   NaN
# mean                   13.212435              8.613228
# std                     2.933508              3.084619
# min                     5.000000              1.600000
# 25%                    11.300000              6.300000
# 50%                    13.100000              9.000000
# 75%                    15.200000             11.300000
# max                    22.100000             14.100000
#
#         Grossnationalincomepercapita
# count                     191.000000
# unique                           NaN
# top                              NaN
# freq                             NaN
# mean                    18368.072461
# std                     19627.352304
# min                       659.730000
# 25%                      4009.435000
# 50%                     11610.910000
# 75%                     26535.420000
# max                    110488.740000

# %% [markdown]
# Some more information:

# %%
hdi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 6 columns):
# Country                         195 non-null object
# Humandevelopmentindex           189 non-null float64
# Lifeexpectancyatbirth           191 non-null float64
# Expectedyearsofschooling        193 non-null float64
# Meanyearsofschooling            189 non-null float64
# Grossnationalincomepercapita    191 non-null float64
# dtypes: float64(5), object(1)
# memory usage: 9.3+ KB

# %% [markdown]
# # INTEGRATING

# %% [markdown]
# Let's check the columns we have for the last three data frames:

# %%
cia.columns
# Out:
# Index(['countries', 'co2_in_MT'], dtype='object')

# %%
demodex.columns
# Out:
# Index(['Country', 'Score', 'Electoralprocessandpluralism',
#        'Functioningofgovernment', 'Politicalparticipation', 'Politicalculture',
#        'Civilliberties', 'Regimetype', 'Continent'],
#       dtype='object')

# %%
hdi.columns
# Out:
# Index(['Country', 'Humandevelopmentindex', 'Lifeexpectancyatbirth',
#        'Expectedyearsofschooling', 'Meanyearsofschooling',
#        'Grossnationalincomepercapita'],
#       dtype='object')

# %% [markdown]
# Integrating data sets needs the following considerations:
#
# * Merging is done on two data frames.
# * You need a common column to be used in both data frames. The column names can be different.
# * The merge can keep only the full coincidences, or also the values not matched, which will help you detect possible extra cleaning.
# * Pandas differentiates calls the **left** from the **right** data frames. The left is the one that requires the merge.

# %% [markdown]
# Let's see the case where the common columns have the same name:

# %%
#hdi and demodex have a common column: Country
hdi.merge(demodex)
# Out:
#                       Country  Humandevelopmentindex  Lifeexpectancyatbirth  \
# 0                      Norway                  0.954                   82.3
# 1                 Switzerland                  0.946                   83.6
# 2                     Ireland                  0.942                   82.1
# 3                     Germany                  0.939                   81.2
# 4                   Australia                  0.938                   83.3
# ..                        ...                    ...                    ...
# 142                      Mali                  0.427                   58.9
# 143                   Burundi                  0.423                   61.2
# 144                      Chad                  0.401                   54.0
# 145  Central African Republic                  0.381                   52.8
# 146                     Niger                  0.377                   62.0
#
#      Expectedyearsofschooling  Meanyearsofschooling  \
# 0                        18.1                  12.6
# 1                        16.2                  13.4
# 2                        18.8                  12.5
# 3                        17.1                  14.1
# 4                        22.1                  12.7
# ..                        ...                   ...
# 142                       7.6                   2.4
# 143                      11.3                   3.1
# 144                       7.5                   2.4
# 145                       7.6                   4.3
# 146                       6.5                   2.0
#
#      Grossnationalincomepercapita Score  Electoralprocessandpluralism  \
# 0                        68058.62  9.87                         10.00
# 1                        59374.73  9.03                          9.58
# 2                        55659.68  9.24                         10.00
# 3                        46945.95  8.68                          9.58
# 4                        44097.02  9.09                         10.00
# ..                            ...   ...                           ...
# 142                       1965.39  4.92                          6.42
# 143                        659.73  2.15                          0.00
# 144                       1715.57  1.61                          0.00
# 145                        776.68  1.32                          1.25
# 146                        912.04  3.29                          2.92
#
#      Functioningofgovernment  Politicalparticipation  Politicalculture  \
# 0                       9.64                   10.00             10.00
# 1                       9.29                    7.78              9.38
# 2                       7.86                    8.33             10.00
# 3                       8.57                    8.33              7.50
# 4                       8.93                    7.78              8.75
# ..                       ...                     ...               ...
# 142                     3.07                    3.89              5.63
# 143                     0.07                    3.33              5.00
# 144                     0.00                    1.67              3.75
# 145                     0.00                    1.11              1.88
# 146                     1.14                    3.33              4.38
#
#      Civilliberties      Regimetype Continent
# 0              9.71  Full democracy    Europe
# 1              9.12  Full democracy    Europe
# 2             10.00  Full democracy    Europe
# 3              9.41  Full democracy    Europe
# 4             10.00  Full democracy   Oceania
# ..              ...             ...       ...
# 142            5.59   Hybrid regime    Africa
# 143            2.35   Authoritarian    Africa
# 144            2.65   Authoritarian    Africa
# 145            2.35   Authoritarian    Africa
# 146            4.71   Authoritarian    Africa
#
# [147 rows x 14 columns]

# %% [markdown]
# Notice that this results shows the full matches by default, resulting in 147 countries. Have you lost countries?

# %%
len(hdi), len(demodex)
# Out:
# (195, 167)

# %% [markdown]
# You can keep the whole **hdi** rows:

# %%
# all hdi and the ones in common with demodex:
hdi.merge(demodex,how='left')
# Out:
#                     Country  Humandevelopmentindex  Lifeexpectancyatbirth  \
# 0                    Norway                  0.954                   82.3
# 1               Switzerland                  0.946                   83.6
# 2                   Ireland                  0.942                   82.1
# 3                   Germany                  0.939                   81.2
# 4    Hong Kong, China (SAR)                  0.939                   84.7
# ..                      ...                    ...                    ...
# 190                  Monaco                    NaN                    NaN
# 191                   Nauru                    NaN                    NaN
# 192              San Marino                    NaN                    NaN
# 193                 Somalia                    NaN                   57.1
# 194                  Tuvalu                    NaN                    NaN
#
#      Expectedyearsofschooling  Meanyearsofschooling  \
# 0                        18.1                  12.6
# 1                        16.2                  13.4
# 2                        18.8                  12.5
# 3                        17.1                  14.1
# 4                        16.5                  12.0
# ..                        ...                   ...
# 190                       NaN                   NaN
# 191                      11.3                   NaN
# 192                      15.1                   NaN
# 193                       NaN                   NaN
# 194                      12.3                   NaN
#
#      Grossnationalincomepercapita Score  Electoralprocessandpluralism  \
# 0                        68058.62  9.87                         10.00
# 1                        59374.73  9.03                          9.58
# 2                        55659.68  9.24                         10.00
# 3                        46945.95  8.68                          9.58
# 4                        60220.80   NaN                           NaN
# ..                            ...   ...                           ...
# 190                           NaN   NaN                           NaN
# 191                      17312.59   NaN                           NaN
# 192                           NaN   NaN                           NaN
# 193                           NaN   NaN                           NaN
# 194                       5408.95   NaN                           NaN
#
#      Functioningofgovernment  Politicalparticipation  Politicalculture  \
# 0                       9.64                   10.00             10.00
# 1                       9.29                    7.78              9.38
# 2                       7.86                    8.33             10.00
# 3                       8.57                    8.33              7.50
# 4                        NaN                     NaN               NaN
# ..                       ...                     ...               ...
# 190                      NaN                     NaN               NaN
# 191                      NaN                     NaN               NaN
# 192                      NaN                     NaN               NaN
# 193                      NaN                     NaN               NaN
# 194                      NaN                     NaN               NaN
#
#      Civilliberties      Regimetype Continent
# 0              9.71  Full democracy    Europe
# 1              9.12  Full democracy    Europe
# 2             10.00  Full democracy    Europe
# 3              9.41  Full democracy    Europe
# 4               NaN             NaN       NaN
# ..              ...             ...       ...
# 190             NaN             NaN       NaN
# 191             NaN             NaN       NaN
# 192             NaN             NaN       NaN
# 193             NaN             NaN       NaN
# 194             NaN             NaN       NaN
#
# [195 rows x 14 columns]

# %% [markdown]
# The merging method **outer** will give you more informative results:

# %%
hdi.merge(demodex,how='outer',indicator=True) # see last column
# Out:
#                               Country  Humandevelopmentindex  \
# 0                              Norway                  0.954
# 1                         Switzerland                  0.946
# 2                             Ireland                  0.942
# 3                             Germany                  0.939
# 4              Hong Kong, China (SAR)                  0.939
# ..                                ...                    ...
# 210                              Iran                    NaN
# 211                              Laos                    NaN
# 212                             Syria                    NaN
# 213  Democratic Republic of the Congo                    NaN
# 214                       North Korea                    NaN
#
#      Lifeexpectancyatbirth  Expectedyearsofschooling  Meanyearsofschooling  \
# 0                     82.3                      18.1                  12.6
# 1                     83.6                      16.2                  13.4
# 2                     82.1                      18.8                  12.5
# 3                     81.2                      17.1                  14.1
# 4                     84.7                      16.5                  12.0
# ..                     ...                       ...                   ...
# 210                    NaN                       NaN                   NaN
# 211                    NaN                       NaN                   NaN
# 212                    NaN                       NaN                   NaN
# 213                    NaN                       NaN                   NaN
# 214                    NaN                       NaN                   NaN
#
#      Grossnationalincomepercapita Score  Electoralprocessandpluralism  \
# 0                        68058.62  9.87                         10.00
# 1                        59374.73  9.03                          9.58
# 2                        55659.68  9.24                         10.00
# 3                        46945.95  8.68                          9.58
# 4                        60220.80   NaN                           NaN
# ..                            ...   ...                           ...
# 210                           NaN  2.38                          0.00
# 211                           NaN  2.14                          0.00
# 212                           NaN  1.43                          0.00
# 213                           NaN  1.13                          0.00
# 214                           NaN  1.08                          0.00
#
#      Functioningofgovernment  Politicalparticipation  Politicalculture  \
# 0                       9.64                   10.00             10.00
# 1                       9.29                    7.78              9.38
# 2                       7.86                    8.33             10.00
# 3                       8.57                    8.33              7.50
# 4                        NaN                     NaN               NaN
# ..                       ...                     ...               ...
# 210                     2.86                    4.44              3.13
# 211                     2.86                    1.67              5.00
# 212                     0.00                    2.78              4.38
# 213                     0.00                    1.67              3.13
# 214                     2.50                    1.67              1.25
#
#      Civilliberties      Regimetype Continent      _merge
# 0              9.71  Full democracy    Europe        both
# 1              9.12  Full democracy    Europe        both
# 2             10.00  Full democracy    Europe        both
# 3              9.41  Full democracy    Europe        both
# 4               NaN             NaN       NaN   left_only
# ..              ...             ...       ...         ...
# 210            1.47   Authoritarian      Asia  right_only
# 211            1.18   Authoritarian      Asia  right_only
# 212            0.00   Authoritarian      Asia  right_only
# 213            0.88   Authoritarian    Africa  right_only
# 214            0.00   Authoritarian      Asia  right_only
#
# [215 rows x 15 columns]

# %% [markdown]
# Let me save this result:

# %%
dirtyMerge1=hdi.merge(demodex,how='outer',indicator=True)

# %% [markdown]
# Now, let me request the countries where the _demodex_ data frame found no match:

# %%
dirtyMerge1.loc[dirtyMerge1['_merge']=='right_only',"Country"]
# Out:
# 195                    South Korea[n 1]
# 196                          Cape Verde
# 197                              Taiwan
# 198                      Czech Republic
# 199                           Hong Kong
# 200                             Moldova
# 201                            Tanzania
# 202                             Bolivia
# 203                         Ivory Coast
# 204                           Palestine
# 205                            Eswatini
# 206               Republic of the Congo
# 207                              Russia
# 208                             Vietnam
# 209                           Venezuela
# 210                                Iran
# 211                                Laos
# 212                               Syria
# 213    Democratic Republic of the Congo
# 214                         North Korea
# Name: Country, dtype: object

# %% [markdown]
# Similarly, let me request the countries where the _hdi_ data frame found no match:

# %%
dirtyMerge1.loc[dirtyMerge1['_merge']=='left_only',"Country"]
# Out:
# 4                   Hong Kong, China (SAR)
# 17                           Liechtenstein
# 22                     Korea (Republic of)
# 25                                 Czechia
# 35                                 Andorra
# 42                       Brunei Darussalam
# 48                      Russian Federation
# 54                                   Palau
# 55                                Barbados
# 59                                 Bahamas
# 61                              Seychelles
# 64              Iran (Islamic Republic of)
# 72                   Saint Kitts and Nevis
# 73                     Antigua and Barbuda
# 77                                 Grenada
# 89                             Saint Lucia
# 94        Saint Vincent and the Grenadines
# 96      Venezuela (Bolivarian Republic of)
# 97                                Dominica
# 102                                 Belize
# 103                               Maldives
# 104                                  Tonga
# 106                  Moldova (Republic of)
# 111                                  Samoa
# 113       Bolivia (Plurinational State of)
# 116                       Marshall Islands
# 117                               Viet Nam
# 118                    Palestine, State of
# 125                             Cabo Verde
# 132                               Kiribati
# 135       Micronesia (Federated States of)
# 136                  Sao Tome and Principe
# 137                                  Congo
# 138                  Eswatini (Kingdom of)
# 139       Lao People's Democratic Republic
# 140                                Vanuatu
# 152                        Solomon Islands
# 153                   Syrian Arab Republic
# 158          Tanzania (United Republic of)
# 164                          Côte d'Ivoire
# 178     Congo (Democratic Republic of the)
# 185                            South Sudan
# 189    Korea (Democratic People's Rep. of)
# 190                                 Monaco
# 191                                  Nauru
# 192                             San Marino
# 193                                Somalia
# 194                                 Tuvalu
# Name: Country, dtype: object

# %% [markdown]
# At this point your data was clean, but yo discover there is still some pending work to do. If you decide to alter the names, you can fo this:

# %%
#dictionary of replacements:
replacements1={'South Korea[n 1]': 'Korea (Republic of)', 
              'Cape Verde':'Cabo Verde',
              'Czech Republic':'Czechia',
              'Hong Kong':'Hong Kong, China (SAR)',
              'Moldova':'Moldova (Republic of)',
              'Bolivia':'Bolivia (Plurinational State of)',
              'Tanzania':'Tanzania (United Republic of)',
              'Palestine':'Palestine, State of',
              'Ivory Coast':"Côte d'Ivoire",
              'Republic of the Congo':'Congo',
              'Venezuela':'Venezuela (Bolivarian Republic of)',
              'Vietnam':'Viet Nam',
              'Eswatini':'Eswatini (Kingdom of)',              
              'Russia':'Russian Federation',
              'Iran':'Iran (Islamic Republic of)',
              'Laos':"Lao People's Democratic Republic",
              'Democratic Republic of the Congo':'Congo (Democratic Republic of the)',
              'Syria':'Syrian Arab Republic',
              'North Korea': "Korea (Democratic People's Rep. of)" #check ""
             }

# replacing
demodex.Country.replace(replacements1,inplace=True)

# %% [markdown]
# You can do your default merge now, and you will get more matches:

# %%
hdi.merge(demodex)
# Out:
#                                  Country  Humandevelopmentindex  \
# 0                                 Norway                  0.954
# 1                            Switzerland                  0.946
# 2                                Ireland                  0.942
# 3                                Germany                  0.939
# 4                 Hong Kong, China (SAR)                  0.939
# ..                                   ...                    ...
# 161                              Burundi                  0.423
# 162                                 Chad                  0.401
# 163             Central African Republic                  0.381
# 164                                Niger                  0.377
# 165  Korea (Democratic People's Rep. of)                    NaN
#
#      Lifeexpectancyatbirth  Expectedyearsofschooling  Meanyearsofschooling  \
# 0                     82.3                      18.1                  12.6
# 1                     83.6                      16.2                  13.4
# 2                     82.1                      18.8                  12.5
# 3                     81.2                      17.1                  14.1
# 4                     84.7                      16.5                  12.0
# ..                     ...                       ...                   ...
# 161                   61.2                      11.3                   3.1
# 162                   54.0                       7.5                   2.4
# 163                   52.8                       7.6                   4.3
# 164                   62.0                       6.5                   2.0
# 165                   72.1                      10.8                   NaN
#
#      Grossnationalincomepercapita Score  Electoralprocessandpluralism  \
# 0                        68058.62  9.87                         10.00
# 1                        59374.73  9.03                          9.58
# 2                        55659.68  9.24                         10.00
# 3                        46945.95  8.68                          9.58
# 4                        60220.80  6.02                          3.58
# ..                            ...   ...                           ...
# 161                        659.73  2.15                          0.00
# 162                       1715.57  1.61                          0.00
# 163                        776.68  1.32                          1.25
# 164                        912.04  3.29                          2.92
# 165                           NaN  1.08                          0.00
#
#      Functioningofgovernment  Politicalparticipation  Politicalculture  \
# 0                       9.64                   10.00             10.00
# 1                       9.29                    7.78              9.38
# 2                       7.86                    8.33             10.00
# 3                       8.57                    8.33              7.50
# 4                       4.36                    6.11              7.50
# ..                       ...                     ...               ...
# 161                     0.07                    3.33              5.00
# 162                     0.00                    1.67              3.75
# 163                     0.00                    1.11              1.88
# 164                     1.14                    3.33              4.38
# 165                     2.50                    1.67              1.25
#
#      Civilliberties        Regimetype Continent
# 0              9.71    Full democracy    Europe
# 1              9.12    Full democracy    Europe
# 2             10.00    Full democracy    Europe
# 3              9.41    Full democracy    Europe
# 4              8.53  Flawed democracy      Asia
# ..              ...               ...       ...
# 161            2.35     Authoritarian    Africa
# 162            2.65     Authoritarian    Africa
# 163            2.35     Authoritarian    Africa
# 164            4.71     Authoritarian    Africa
# 165            0.00     Authoritarian      Asia
#
# [166 rows x 14 columns]

# %% [markdown]
# Let's save this last result:

# %%
hdidemo=hdi.merge(demodex)

# %% [markdown]
# Now, let's merge this result with the other one whose common column has a different name:

# %%
hdidemo.merge(cia,left_on="Country", right_on='countries')
# Out:
#                       Country  Humandevelopmentindex  Lifeexpectancyatbirth  \
# 0                      Norway                  0.954                   82.3
# 1                 Switzerland                  0.946                   83.6
# 2                     Ireland                  0.942                   82.1
# 3                     Germany                  0.939                   81.2
# 4                   Australia                  0.938                   83.3
# ..                        ...                    ...                    ...
# 142                      Mali                  0.427                   58.9
# 143                   Burundi                  0.423                   61.2
# 144                      Chad                  0.401                   54.0
# 145  Central African Republic                  0.381                   52.8
# 146                     Niger                  0.377                   62.0
#
#      Expectedyearsofschooling  Meanyearsofschooling  \
# 0                        18.1                  12.6
# 1                        16.2                  13.4
# 2                        18.8                  12.5
# 3                        17.1                  14.1
# 4                        22.1                  12.7
# ..                        ...                   ...
# 142                       7.6                   2.4
# 143                      11.3                   3.1
# 144                       7.5                   2.4
# 145                       7.6                   4.3
# 146                       6.5                   2.0
#
#      Grossnationalincomepercapita Score  Electoralprocessandpluralism  \
# 0                        68058.62  9.87                         10.00
# 1                        59374.73  9.03                          9.58
# 2                        55659.68  9.24                         10.00
# 3                        46945.95  8.68                          9.58
# 4                        44097.02  9.09                         10.00
# ..                            ...   ...                           ...
# 142                       1965.39  4.92                          6.42
# 143                        659.73  2.15                          0.00
# 144                       1715.57  1.61                          0.00
# 145                        776.68  1.32                          1.25
# 146                        912.04  3.29                          2.92
#
#      Functioningofgovernment  Politicalparticipation  Politicalculture  \
# 0                       9.64                   10.00             10.00
# 1                       9.29                    7.78              9.38
# 2                       7.86                    8.33             10.00
# 3                       8.57                    8.33              7.50
# 4                       8.93                    7.78              8.75
# ..                       ...                     ...               ...
# 142                     3.07                    3.89              5.63
# 143                     0.07                    3.33              5.00
# 144                     0.00                    1.67              3.75
# 145                     0.00                    1.11              1.88
# 146                     1.14                    3.33              4.38
#
#      Civilliberties      Regimetype Continent                 countries  \
# 0              9.71  Full democracy    Europe                    Norway
# 1              9.12  Full democracy    Europe               Switzerland
# 2             10.00  Full democracy    Europe                   Ireland
# 3              9.41  Full democracy    Europe                   Germany
# 4             10.00  Full democracy   Oceania                 Australia
# ..              ...             ...       ...                       ...
# 142            5.59   Hybrid regime    Africa                      Mali
# 143            2.35   Authoritarian    Africa                   Burundi
# 144            2.65   Authoritarian    Africa                      Chad
# 145            2.35   Authoritarian    Africa  Central African Republic
# 146            4.71   Authoritarian    Africa                     Niger
#
#        co2_in_MT
# 0     39800000.0
# 1     38950000.0
# 2     36910000.0
# 3    847600000.0
# 4    439100000.0
# ..           ...
# 142    3388000.0
# 143     217000.0
# 144     342200.0
# 145     413800.0
# 146    2534000.0
#
# [147 rows x 16 columns]

# %% [markdown]
# We are losing countries again. Let's use the **outer** method.

# %%
dirtyMerge2=hdidemo.merge(cia,left_on="Country", right_on='countries',how='outer',indicator=True)

# %%
dirtyMerge2
# Out:
#                     Country  Humandevelopmentindex  Lifeexpectancyatbirth  \
# 0                    Norway                  0.954                   82.3
# 1               Switzerland                  0.946                   83.6
# 2                   Ireland                  0.942                   82.1
# 3                   Germany                  0.939                   81.2
# 4    Hong Kong, China (SAR)                  0.939                   84.7
# ..                      ...                    ...                    ...
# 230                     NaN                    NaN                    NaN
# 231                     NaN                    NaN                    NaN
# 232                     NaN                    NaN                    NaN
# 233                     NaN                    NaN                    NaN
# 234                     NaN                    NaN                    NaN
#
#      Expectedyearsofschooling  Meanyearsofschooling  \
# 0                        18.1                  12.6
# 1                        16.2                  13.4
# 2                        18.8                  12.5
# 3                        17.1                  14.1
# 4                        16.5                  12.0
# ..                        ...                   ...
# 230                       NaN                   NaN
# 231                       NaN                   NaN
# 232                       NaN                   NaN
# 233                       NaN                   NaN
# 234                       NaN                   NaN
#
#      Grossnationalincomepercapita Score  Electoralprocessandpluralism  \
# 0                        68058.62  9.87                         10.00
# 1                        59374.73  9.03                          9.58
# 2                        55659.68  9.24                         10.00
# 3                        46945.95  8.68                          9.58
# 4                        60220.80  6.02                          3.58
# ..                            ...   ...                           ...
# 230                           NaN   NaN                           NaN
# 231                           NaN   NaN                           NaN
# 232                           NaN   NaN                           NaN
# 233                           NaN   NaN                           NaN
# 234                           NaN   NaN                           NaN
#
#      Functioningofgovernment  Politicalparticipation  Politicalculture  \
# 0                       9.64                   10.00             10.00
# 1                       9.29                    7.78              9.38
# 2                       7.86                    8.33             10.00
# 3                       8.57                    8.33              7.50
# 4                       4.36                    6.11              7.50
# ..                       ...                     ...               ...
# 230                      NaN                     NaN               NaN
# 231                      NaN                     NaN               NaN
# 232                      NaN                     NaN               NaN
# 233                      NaN                     NaN               NaN
# 234                      NaN                     NaN               NaN
#
#      Civilliberties        Regimetype Continent       countries     co2_in_MT  \
# 0              9.71    Full democracy    Europe          Norway  3.980000e+07
# 1              9.12    Full democracy    Europe     Switzerland  3.895000e+07
# 2             10.00    Full democracy    Europe         Ireland  3.691000e+07
# 3              9.41    Full democracy    Europe         Germany  8.476000e+08
# 4              8.53  Flawed democracy      Asia             NaN           NaN
# ..              ...               ...       ...             ...           ...
# 230             NaN               NaN       NaN         Vietnam  2.353000e+08
# 231             NaN               NaN       NaN  Virgin Islands  2.764000e+06
# 232             NaN               NaN       NaN       West Bank  3.113000e+06
# 233             NaN               NaN       NaN  Western Sahara  2.684000e+05
# 234             NaN               NaN       NaN           World  3.362000e+10
#
#          _merge
# 0          both
# 1          both
# 2          both
# 3          both
# 4     left_only
# ..          ...
# 230  right_only
# 231  right_only
# 232  right_only
# 233  right_only
# 234  right_only
#
# [235 rows x 17 columns]

# %%
dirtyMerge2.loc[dirtyMerge2['_merge']=='left_only',"Country"].to_list()
# Out:
# ['Hong Kong, China (SAR)',
#  'Korea (Republic of)',
#  'Russian Federation',
#  'Iran (Islamic Republic of)',
#  'Venezuela (Bolivarian Republic of)',
#  'Moldova (Republic of)',
#  'Bolivia (Plurinational State of)',
#  'Viet Nam',
#  'Palestine, State of',
#  'Congo',
#  'Eswatini (Kingdom of)',
#  "Lao People's Democratic Republic",
#  'Myanmar',
#  'Syrian Arab Republic',
#  'Tanzania (United Republic of)',
#  "Côte d'Ivoire",
#  'Gambia',
#  'Congo (Democratic Republic of the)',
#  "Korea (Democratic People's Rep. of)"]

# %%
dirtyMerge2.loc[dirtyMerge2['_merge']=='right_only',"countries"].to_list()
# Out:
# ['American Samoa',
#  'Antigua and Barbuda',
#  'Aruba',
#  'Bahamas, The',
#  'Barbados',
#  'Belize',
#  'Bermuda',
#  'Bolivia',
#  'British Virgin Islands',
#  'Brunei',
#  'Burma',
#  'Cayman Islands',
#  'Congo, Democratic Republic of the',
#  'Congo, Republic of the',
#  'Cook Islands',
#  "Cote d'Ivoire",
#  'Dominica',
#  'Eswatini',
#  'European Union',
#  'Falkland Islands (Islas Malvinas)',
#  'Faroe Islands',
#  'French Polynesia',
#  'Gambia, The',
#  'Gibraltar',
#  'Greenland',
#  'Grenada',
#  'Guam',
#  'Hong Kong',
#  'Iran',
#  'Jersey',
#  'Kiribati',
#  'Korea, North',
#  'Korea, South',
#  'Kosovo',
#  'Laos',
#  'Macau',
#  'Maldives',
#  'Marshall Islands',
#  'Micronesia, Federated States of',
#  'Moldova',
#  'Montserrat',
#  'Nauru',
#  'New Caledonia',
#  'Niue',
#  'Puerto Rico',
#  'Russia',
#  'Saint Helena, Ascension, and Tristan da Cunha',
#  'Saint Kitts and Nevis',
#  'Saint Lucia',
#  'Saint Pierre and Miquelon',
#  'Saint Vincent and the Grenadines',
#  'Samoa',
#  'Sao Tome and Principe',
#  'Seychelles',
#  'Solomon Islands',
#  'Somalia',
#  'South Sudan',
#  'Syria',
#  'Taiwan',
#  'Tanzania',
#  'Tonga',
#  'Turks and Caicos Islands',
#  'Vanuatu',
#  'Venezuela',
#  'Vietnam',
#  'Virgin Islands',
#  'West Bank',
#  'Western Sahara',
#  'World']

# %%
replacements2={'Hong Kong, China (SAR)':'Hong Kong',
 'Korea (Republic of)':'Korea, South',
 'Russian Federation':'Russia',
 'Iran (Islamic Republic of)':'Iran',
 'Venezuela (Bolivarian Republic of)':'Venezuela',
 'Moldova (Republic of)':'Moldova',
 'Bolivia (Plurinational State of)':'Bolivia',
 'Viet Nam':'Vietnam',
 'Congo':'Congo, Republic of the',
 'Eswatini (Kingdom of)':'Eswatini',
 "Lao People's Democratic Republic":'Laos',
 'Myanmar':'Burma',
 'Syrian Arab Republic':'Syria',
 'Tanzania (United Republic of)':'Tanzania',
 "Côte d'Ivoire":"Cote d'Ivoire",
 'Gambia':'Gambia, The',
 'Congo (Democratic Republic of the)':'Congo, Democratic Republic of the'
}
 
 
 # replacing
hdidemo.Country.replace(replacements2,inplace=True)

# %% [markdown]
# Then:

# %%
hdidemo.merge(cia,left_on="Country", right_on='countries')
# Out:
#                       Country  Humandevelopmentindex  Lifeexpectancyatbirth  \
# 0                      Norway                  0.954                   82.3
# 1                 Switzerland                  0.946                   83.6
# 2                     Ireland                  0.942                   82.1
# 3                     Germany                  0.939                   81.2
# 4                   Hong Kong                  0.939                   84.7
# ..                        ...                    ...                    ...
# 159                      Mali                  0.427                   58.9
# 160                   Burundi                  0.423                   61.2
# 161                      Chad                  0.401                   54.0
# 162  Central African Republic                  0.381                   52.8
# 163                     Niger                  0.377                   62.0
#
#      Expectedyearsofschooling  Meanyearsofschooling  \
# 0                        18.1                  12.6
# 1                        16.2                  13.4
# 2                        18.8                  12.5
# 3                        17.1                  14.1
# 4                        16.5                  12.0
# ..                        ...                   ...
# 159                       7.6                   2.4
# 160                      11.3                   3.1
# 161                       7.5                   2.4
# 162                       7.6                   4.3
# 163                       6.5                   2.0
#
#      Grossnationalincomepercapita Score  Electoralprocessandpluralism  \
# 0                        68058.62  9.87                         10.00
# 1                        59374.73  9.03                          9.58
# 2                        55659.68  9.24                         10.00
# 3                        46945.95  8.68                          9.58
# 4                        60220.80  6.02                          3.58
# ..                            ...   ...                           ...
# 159                       1965.39  4.92                          6.42
# 160                        659.73  2.15                          0.00
# 161                       1715.57  1.61                          0.00
# 162                        776.68  1.32                          1.25
# 163                        912.04  3.29                          2.92
#
#      Functioningofgovernment  Politicalparticipation  Politicalculture  \
# 0                       9.64                   10.00             10.00
# 1                       9.29                    7.78              9.38
# 2                       7.86                    8.33             10.00
# 3                       8.57                    8.33              7.50
# 4                       4.36                    6.11              7.50
# ..                       ...                     ...               ...
# 159                     3.07                    3.89              5.63
# 160                     0.07                    3.33              5.00
# 161                     0.00                    1.67              3.75
# 162                     0.00                    1.11              1.88
# 163                     1.14                    3.33              4.38
#
#      Civilliberties        Regimetype Continent                 countries  \
# 0              9.71    Full democracy    Europe                    Norway
# 1              9.12    Full democracy    Europe               Switzerland
# 2             10.00    Full democracy    Europe                   Ireland
# 3              9.41    Full democracy    Europe                   Germany
# 4              8.53  Flawed democracy      Asia                 Hong Kong
# ..              ...               ...       ...                       ...
# 159            5.59     Hybrid regime    Africa                      Mali
# 160            2.35     Authoritarian    Africa                   Burundi
# 161            2.65     Authoritarian    Africa                      Chad
# 162            2.35     Authoritarian    Africa  Central African Republic
# 163            4.71     Authoritarian    Africa                     Niger
#
#        co2_in_MT
# 0     39800000.0
# 1     38950000.0
# 2     36910000.0
# 3    847600000.0
# 4    102500000.0
# ..           ...
# 159    3388000.0
# 160     217000.0
# 161     342200.0
# 162     413800.0
# 163    2534000.0
#
# [164 rows x 16 columns]

# %%
hdidemocia=hdidemo.merge(cia,left_on="Country", right_on='countries')

# %%
hdidemocia.dtypes
# Out:
# Country                           object
# Humandevelopmentindex            float64
# Lifeexpectancyatbirth            float64
# Expectedyearsofschooling         float64
# Meanyearsofschooling             float64
# Grossnationalincomepercapita     float64
# Score                             object
# Electoralprocessandpluralism     float64
# Functioningofgovernment          float64
# Politicalparticipation           float64
# Politicalculture                 float64
# Civilliberties                   float64
# Regimetype                      category
# Continent                       category
# countries                         object
# co2_in_MT                        float64
# dtype: object

# %% [markdown]
# ____
# ____
#
#
# ### <font color="red">Saving File to Disk</font>

# %% [markdown]
# #### For future use in Python:

# %%
hdidemocia.to_pickle("hdidemocia.pkl")
# you will need: DF=pd.read_pickle("hdidemocia.pkl")
# or:
# from urllib.request import urlopen
# DF=pd.read_pickle(urlopen("https://..../hdidemocia.pkl"),compression=None)

# %% [markdown]
# #### For future  use in R:

# %%
# this makes the data converted to RDS

from rpy2.robjects import pandas2ri
pandas2ri.activate()

from rpy2.robjects.packages import importr

base = importr('base')
base.saveRDS(hdidemocia,file="hdidemocia.RDS")

#In R, you call it with: DF = readRDS("hdidemocia.RDS")
#or, if iyou read from cloud: DF = readRDS(url("https://..../hdidemocia.RDS")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-156-df28fe549a60> in <module>()
# ----> 1 from rpy2.robjects import pandas2ri
#       2 pandas2ri.activate()
#
# ~\Anaconda3\lib\site-packages\rpy2\robjects\pandas2ri.py in <module>()
#      21 import numpy
#      22 import pytz
# ---> 23 import tzlocal
#      24 import warnings
#      25
#
# ModuleNotFoundError: No module named 'tzlocal'

# %%
# get the file to your computer:
# if it doesn't work, try this: https://stackoverflow.com/questions/53581023/google-colab-file-download-failed-to-fetch-error
from google.colab import files

files.download('hdidem.RDS')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-157-7babf26c1303> in <module>()
#       1 # get the file to your computer:
# ----> 2 from google.colab import files
#       3
#       4 files.download('hdidem.RDS')
#
# ModuleNotFoundError: No module named 'google.colab'

# %% [markdown]
# ## Exercise 11

# %% [markdown]
# 1. Reload the original data from HDI.
# 2. Create a new data frame, with ONLY the name of countries and a dichotomical value that has a 1 if above the median HDI, and 0 otherwise.
# 3. Merge this new data frame with the **hdidemocia** data frame. Name the final output **hdidemocia2**
# 4. Save **hdidemocia2** for future use in Python and in R.

# %% [markdown]
# ## Exercise 12
#
# 1. Clean and format your data set, the one you presented last week.
# 2. Save the result for future use in Python and in R.
