# %%
import pandas as pd

GitLinkDTA='https://github.com/reconjohn/evans/raw/master/hsb_ok.dta'
dataStata=pd.read_stata(GitLinkDTA,convert_categoricals=False)

# %%
dataStata.head()
# Out:
#       id  sex  race  ses  sctyp  hsp  locus  concpt   mot   car   rdg  wrtg  \
# 0      1  2.0   2.0  1.0    1.0  3.0   0.29    0.88  0.67  10.0  33.6  43.7
# 1      2  1.0   2.0  1.0    1.0  2.0  -0.42    0.03  0.33   2.0  46.9  35.9
# 2      3  2.0   2.0  1.0    1.0  2.0   0.71    0.03  0.67   9.0  41.6  59.3
# 3      4  2.0   2.0  2.0    1.0  3.0   0.06    0.03  0.00  15.0  38.9  41.1
# 4      5  2.0   2.0  2.0    1.0  3.0   0.22   -0.28  0.00   1.0  36.3  48.9
#
#    math   sci   civ
# 0  40.2  39.0  40.6
# 1  41.9  36.3  45.6
# 2  41.9  44.4  45.6
# 3  32.7  41.7  40.6
# 4  39.5  41.7  45.6

# %%
DataStata=pd.read_stata(GitLinkDTA,convert_categoricals=True)
DataStata.head()
# Out:
#       id     sex   race     ses   sctyp                   hsp  locus  concpt  \
# 0      1  Female  Asian     Low  Public  Vocational/Technical   0.29    0.88
# 1      2    Male  Asian     Low  Public  Academic preparatory  -0.42    0.03
# 2      3  Female  Asian     Low  Public  Academic preparatory   0.71    0.03
# 3      4  Female  Asian  Medium  Public  Vocational/Technical   0.06    0.03
# 4      5  Female  Asian  Medium  Public  Vocational/Technical   0.22   -0.28
#
#     mot             car   rdg  wrtg  math   sci   civ
# 0  0.67  Professional_2  33.6  43.7  40.2  39.0  40.6
# 1  0.33       Craftsman  46.9  35.9  41.9  36.3  45.6
# 2  0.67  Professional_1  41.6  59.3  41.9  44.4  45.6
# 3  0.00         Service  38.9  41.1  32.7  41.7  40.6
# 4  0.00        Clerical  36.3  48.9  39.5  41.7  45.6

# %%
GitLinkXLS='https://github.com/reconjohn/evans/raw/master/hsb_ok.xlsx'
#dataExcel=
pd.read_excel(GitLinkXLS).head()
# Out:
#    ID  SEX  RACE  SES  SCTYP  HSP  LOCUS  CONCPT   MOT  CAR   RDG  WRTG  MATH  \
# 0   1    2     2    1      1    3   0.29    0.88  0.67   10  33.6  43.7  40.2
# 1   2    1     2    1      1    2  -0.42    0.03  0.33    2  46.9  35.9  41.9
# 2   3    2     2    1      1    2   0.71    0.03  0.67    9  41.6  59.3  41.9
# 3   4    2     2    2      1    3   0.06    0.03  0.00   15  38.9  41.1  32.7
# 4   5    2     2    2      1    3   0.22   -0.28  0.00    1  36.3  48.9  39.5
#
#     SCI   CIV
# 0  39.0  40.6
# 1  36.3  45.6
# 2  44.4  45.6
# 3  41.7  40.6
# 4  41.7  45.6

# %%
# !pip install pyreadstat

# %%
import pyreadstat
from urllib.request import urlopen
GitLinkSAV="https://github.com/reconjohn/evans/raw/master/hsb_ok.sav"
response = urlopen(GitLinkSAV) # open link
content = response.read() # read contents
fhandle = open('savFromGit.sav', 'wb') # open a file
fhandle.write(content) # save contents in that file
fhandle.close() # close the file

# %%
df= pd.read_spss("savFromGit.sav",convert_categoricals=True)

# here it is
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-be814e72b8ba> in <module>()
# ----> 1 df= pd.read_spss("savFromGit.sav",convert_categoricals=True)
#       2
#       3 # here it is
#       4 df
#
# AttributeError: module 'pandas' has no attribute 'read_spss'

# %%
from IPython.display import IFrame  
fromGoogle="https://docs.google.com/spreadsheets/d/e/2PACX-1vQeDp3EvLEfjdGnlfxZHS5JIPks72d1n9xzu5pETHt3J5EkZFN6beK3PeDmGOqSzkQi8iPQrtXSCITj/pubhtml?gid=1054674892&amp;single=true&amp;widget=true&amp;headers=false" 
IFrame(fromGoogle, width=900, height=300)
# Out:
#         <iframe
#             width="900"
#             height="300"
#             src="https://docs.google.com/spreadsheets/d/e/2PACX-1vQeDp3EvLEfjdGnlfxZHS5JIPks72d1n9xzu5pETHt3J5EkZFN6beK3PeDmGOqSzkQi8iPQrtXSCITj/pubhtml?gid=1054674892&amp;single=true&amp;widget=true&amp;headers=false"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
link="https://docs.google.com/spreadsheets/d/e/2PACX-1vQ0aXwHWItgPXskWG5OXGO6h17ubTouc-VMEnq2F6SwnvX0lQNIRbJ7DctJIrzpRxnJP8vsMOf8f46l/pub?gid=1949932199&single=true&output=csv" 
fromGoogle=pd.read_csv(link)

fromGoogle.head()
# Out:
#    ID  SEX  RACE  SES  SCTYP  HSP  LOCUS  CONCPT   MOT  CAR   RDG  WRTG  MATH  \
# 0   1    2     2    1      1    3   0.29    0.88  0.67   10  33.6  43.7  40.2
# 1   2    1     2    1      1    2  -0.42    0.03  0.33    2  46.9  35.9  41.9
# 2   3    2     2    1      1    2   0.71    0.03  0.67    9  41.6  59.3  41.9
# 3   4    2     2    2      1    3   0.06    0.03  0.00   15  38.9  41.1  32.7
# 4   5    2     2    2      1    3   0.22   -0.28  0.00    1  36.3  48.9  39.5
#
#     SCI   CIV
# 0  39.0  40.6
# 1  36.3  45.6
# 2  44.4  45.6
# 3  41.7  40.6
# 4  41.7  45.6

# %%
from IPython.display import IFrame  
fromAPI="https://dev.socrata.com/foundry/data.seattle.gov/kzjm-xkqj" 
IFrame(fromAPI, width=900, height=500)
# Out:
#         <iframe
#             width="900"
#             height="500"
#             src="https://dev.socrata.com/foundry/data.seattle.gov/kzjm-xkqj"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from sodapy import Socrata

client = Socrata("data.seattle.gov", None)
results = client.get("kzjm-xkqj", limit=1000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
results_df.head()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#   :@computed_region_2day_rhn5 :@computed_region_cyqu_gs94  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         122                           1
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#   :@computed_region_kuhn_3gp2 :@computed_region_q256_3sug  \
# 0                           4                       18789
# 1                          49                       18795
# 2                          26                       19579
# 3                           5                       18376
# 4                           7                       19576
#
#   :@computed_region_ru88_fbhk                      address  \
# 0                           8  15TH AV E / E REPUBLICAN ST
# ...

# %%
from IPython.display import IFrame  
wikiLink="https://en.wikipedia.org/wiki/Democracy_Index" 
IFrame(wikiLink, width=700, height=300)
# Out:
#         <iframe
#             width="700"
#             height="300"
#             src="https://en.wikipedia.org/wiki/Democracy_Index"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
DFs=pd.read_html(wikiLink,header=0,flavor='bs4',attrs={'class': 'wikitable'})

# %%
type(DFs)
# Out:
# list

# %%
len(DFs)
# Out:
# 3

# %%
DFs[0].head()
# Out:
#   Rank      Country Score Electoral processand pluralism  \
# 0    1       Norway  9.87                          10.00
# 1    2      Iceland  9.58                          10.00
# 2    3       Sweden  9.39                           9.58
# 3    4  New Zealand  9.26                          10.00
# 4    5      Denmark  9.22                          10.00
#
#   Functioning ofgovernment Politicalparticipation Politicalculture  \
# 0                     9.64                  10.00            10.00
# 1                     9.29                   8.89            10.00
# 2                     9.64                   8.33            10.00
# 3                     9.29                   8.89             8.13
# 4                     9.29                   8.33             9.38
#
#   Civilliberties      Regimetype Continent
# 0           9.71  Full democracy    Europe
# 1           9.71  Full democracy    Europe
# 2           9.41  Full democracy    Europe
# ...

# %%
Link="https://en.wikipedia.org/wiki/List_of_freedom_indices" 
IFrame(Link, width=700, height=300)
# Out:
#         <iframe
#             width="700"
#             height="300"
#             src="https://en.wikipedia.org/wiki/List_of_freedom_indices"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
DFs=pd.read_html(Link,header=0,flavor='bs4',attrs={'class': 'wikitable'})
type(DFs)
# Out:
# list

# %%
len(DFs)
# Out:
# 2

# %%
DFs[1].head()
# Out:
#        Country Freedom in the World 2019[10]  \
# 0  Afghanistan                      not free
# 1      Albania                   partly free
# 2      Algeria                      not free
# 3      Andorra                          free
# 4       Angola                      not free
#
#   2019 Index of Economic Freedom[11] 2019 Press Freedom Index[3]  \
# 0                      mostly unfree         difficult situation
# 1                    moderately free         noticeable problems
# 2                          repressed         difficult situation
# 3                                NaN      satisfactory situation
# 4                      mostly unfree         noticeable problems
#
#   2018 Democracy Index[13]
# 0     authoritarian regime
# 1            hybrid regime
# 2     authoritarian regime
# 3                      NaN
# 4     authoritarian regime
