# %% [markdown]
# ### CIA

# %%
import pandas as pd

link1="https://www.cia.gov/library/publications/resources/the-world-factbook/fields/274.html"

cia=pd.read_html(link1,header=0,attrs={'id': 'fieldListing'})[0]

# %%
# renaming both columns:
OldToNew={cia.columns[0]:'countries',cia.columns[1]:'co2'}
cia.rename(columns=OldToNew,inplace=True)

# cleaning Country (preventive)
cia.countries=cia.countries.str.strip()

# splitting second column, keeping main information. This overwrites co2.
result1=cia.co2.str.split(' Mt',expand=True)[0]
cia=cia.assign(co2=result1)

# extracting number and text from co2 into a dataframe, adding those to CIA
result2=cia.co2.str.extract('(?P<number>\d+\,*\.*\d*)\s*(?P<text>\D+)*')
cia=cia.assign(value=result2.number,
               unit=result2.text)

# deleting comma from newly created column'value'
cia.value=cia.value.str.replace(",","")

# recoding newly created column'unit':
replacements={'million': 10**6, "billion": 10**9,None:10**0}
cia.unit.replace(replacements,inplace=True)

# dropping unneeded column:
cia.drop(columns='co2',inplace=True)

# %%
# cia.countries.str.strip()
# Out:
# 0         Afghanistan
# 1             Albania
# 2             Algeria
# 3      American Samoa
# 4              Angola
#             ...
# 211    Western Sahara
# 212             World
# 213             Yemen
# 214            Zambia
# 215          Zimbabwe
# Name: countries, Length: 216, dtype: object

# %%
# Formatting numeric columns:

# value is text, now to numeric type:
cia=cia.assign(value=pd.to_numeric(cia.value))

# once value and unit are numeric, 
# new column 'co2_in_MT' is created from multiplying both.
cia=cia.assign(co2_in_MT=cia.value*cia.unit)

# value and unit were temporary columns, they can go now.
cia.drop(columns=['value','unit'],inplace=True)

# %%
cia.head()
# Out:
#         countries   co2_in_MT
# 0     Afghanistan       9.067
# 1         Albania       4.500
# 2         Algeria     135.900
# 3  American Samoa  361100.000
# 4          Angola      20.950

# %%
cia.dtypes
# Out:
# countries     object
# co2_in_MT    float64
# dtype: object

# %% [markdown]
# ### Decmocracy

# %%
import pandas as pd
link2= "https://en.wikipedia.org/wiki/Democracy_Index" 

# getting the data frame in one step:
demodex=pd.read_html(link2,header=0,flavor='bs4',attrs={'class': 'wikitable sortable'})[0]

# %%
#bye row 167, and Rank
demodex=demodex.drop(index=167,columns=['Rank','Score'])

# Simplifying column names to facilitate further work:
demodex.columns=demodex.columns.str.replace('\s+',"")

# preventive cleaning of numeric cell values:
NumericColNames=demodex.iloc[:,1:6].columns
badSymbols=[]
for columnName in NumericColNames:
    for cell in demodex[columnName]:
        try:
            float(cell)
        except:
            if cell not in badSymbols:
                badSymbols.append(cell)
            
import numpy as np  
demodex.loc[:,NumericColNames].replace(to_replace=badSymbols,value=np.nan,inplace=True)

# see if we have some strange value in the categorical columns:
demodex.iloc[:,-2::].apply(set).to_list()
# Out:
# [{'Authoritarian', 'Flawed democracy', 'Full democracy', 'Hybrid regime'},
#  {'Africa',
#   'Asia',
#   'Europe',
#   'Europe/Asia',
#   'North America',
#   'Oceania',
#   'South America'}]

# %%
# Formatting numeric columns

# save column names of the columns to change:
colsToChange=demodex.iloc[:,1:6].columns
# make changes NOT using iloc:
demodex[colsToChange]=demodex[colsToChange].apply(pd.to_numeric)


# Formatting categorical columns
# NOMINAL
demodex.Continent=pd.Categorical(demodex.Continent)
# ORDINAL
#rewrite the levels in order:
correctLevels=['Authoritarian', 'Hybrid regime', 'Flawed democracy','Full democracy']
demodex.Regimetype=pd.Categorical(demodex.Regimetype,categories=correctLevels,ordered=True)

# %%
demodex.dtypes
# Out:
# Country                           object
# Electoralprocessandpluralism     float64
# Functioningofgovernment          float64
# Politicalparticipation           float64
# Politicalculture                 float64
# Civilliberties                   float64
# Regimetype                      category
# Continent                       category
# dtype: object

# %%
demodex.Continent.cat.ordered
# Out:
# False

# %%
demodex.Regimetype.cat.ordered
# Out:
# True

# %% [markdown]
# ### Human development

# %%
link1="https://docs.google.com/spreadsheets/d/e/2PACX-1vRojxNKqFZMSqPbZA0D6DYsuRqBuDmZuyK0DFbbatwTQIfClU2lwoCYsEKalaYv_IorAYSmMeTWmlKF/pub?gid=239626258&single=true&output=csv"

# %%
# need to call pandas:

import pandas as pd

hdi=pd.read_csv(link1)

# %%
# Is the header in the right place:
hdi.head(10)
# Out:
#   Unnamed: 0 Table 1. Human Development Index and its components  \
# 0        NaN                                                NaN
# 1        NaN                                                NaN
# 2        NaN                                                NaN
# 3        NaN                                                NaN
# 4   HDI rank                                            Country
# 5        NaN                                                NaN
# 6        NaN                        VERY HIGH HUMAN DEVELOPMENT
# 7          1                                             Norway
# 8          2                                        Switzerland
# 9          3                                            Ireland
#
#                       Unnamed: 2  Unnamed: 3                Unnamed: 4  \
# 0                            NaN         NaN                       NaN
# 1                            NaN         NaN                      SDG3
# 2                            NaN         NaN                       NaN
# 3  Human development index (HDI)         NaN  Life expectancy at birth
# 4                  (index value)         NaN                   (years)
# 5                           2018         NaN                      2018
# 6                            NaN         NaN                       NaN
# 7                           0.95         NaN                     82.27
# 8                           0.95         NaN                     83.63
# 9                           0.94         NaN                      82.1
#
#   Unnamed: 5                   Unnamed: 6 Unnamed: 7               Unnamed: 8  \
# 0        NaN                          NaN        NaN                      NaN
# 1        NaN                       SDG4.3        NaN                   SDG4.6
# 2        NaN                          NaN        NaN                      NaN
# 3        NaN  Expected years of schooling        NaN  Mean years of schooling
# 4        NaN                      (years)        NaN                  (years)
# 5        NaN                         2018          a                     2018
# 6        NaN                          NaN        NaN                      NaN
# 7        NaN                        18.06          b                    12.57
# 8        NaN                        16.21        NaN                    13.38
# 9        NaN                        18.79          b                    12.53
#
#   Unnamed: 9                             Unnamed: 10 Unnamed: 11  \
# 0        NaN                                     NaN         NaN
# 1        NaN                                  SDG8.5         NaN
# 2        NaN                                     NaN         NaN
# 3        NaN  Gross national income (GNI) per capita         NaN
# 4        NaN                            (2011 PPP $)         NaN
# 5          a                                    2018         NaN
# 6        NaN                                     NaN         NaN
# 7        NaN                                68058.62         NaN
# 8        NaN                                59374.73         NaN
# 9          c                                55659.68         NaN
#
#                           Unnamed: 12  Unnamed: 13 Unnamed: 14
# 0                                 NaN          NaN         NaN
# 1                                 NaN          NaN         NaN
# 2                                 NaN          NaN         NaN
# 3  GNI per capita rank minus HDI rank          NaN    HDI rank
# 4                                 NaN          NaN         NaN
# 5                                2018          NaN        2017
# 6                                 NaN          NaN         NaN
# 7                                   5          NaN           1
# 8                                   8          NaN           2
# 9                                   9          NaN           3

# %%
# for the first two columns:
hdi.iloc[4,:2].tolist()
# Out:
# ['HDI rank', 'Country']

# %%
# for the rest of columns columns:
hdi.iloc[3,2:].tolist()
# Out:
# ['Human development index (HDI)',
#  nan,
#  'Life expectancy at birth',
#  nan,
#  'Expected years of schooling',
#  nan,
#  'Mean years of schooling',
#  nan,
#  'Gross national income (GNI) per capita',
#  nan,
#  'GNI per capita rank minus HDI rank',
#  nan,
#  'HDI rank']

# %%
# saving headers:
CurrentHeaders=hdi.iloc[4,:2].tolist()+hdi.iloc[3,2:].tolist()

# you saved this:
CurrentHeaders
# Out:
# ['HDI rank',
#  'Country',
#  'Human development index (HDI)',
#  nan,
#  'Life expectancy at birth',
#  nan,
#  'Expected years of schooling',
#  nan,
#  'Mean years of schooling',
#  nan,
#  'Gross national income (GNI) per capita',
#  nan,
#  'GNI per capita rank minus HDI rank',
#  nan,
#  'HDI rank']

# %%
# PREVIEW: deleting rows, NORWAY should be the first row:
hdi.drop(index=range(0,7)) #7 in range() will not be erased.
# Out:
#     Unnamed: 0 Table 1. Human Development Index and its components Unnamed: 2  \
# 7            1                                             Norway        0.95
# 8            2                                        Switzerland        0.95
# 9            3                                            Ireland        0.94
# 10           4                                            Germany        0.94
# 11           4                             Hong Kong, China (SAR)        0.94
# ..         ...                                                ...         ...
# 264        NaN                          Column 2: UNDESA (2019b).         NaN
# 265        NaN  Column 3: UNESCO Institute for Statistics (201...         NaN
# 266        NaN  Column 4: UNESCO Institute for Statistics (201...         NaN
# 267        NaN  Column 5: World Bank (2019a), IMF (2019) and U...         NaN
# 268        NaN  Column 6: Calculated based on data in columns ...         NaN
#
#      Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 7           NaN      82.27        NaN      18.06          b      12.57
# 8           NaN      83.63        NaN      16.21        NaN      13.38
# 9           NaN       82.1        NaN      18.79          b      12.53
# 10          NaN      81.18        NaN       17.1        NaN      14.13
# 11          NaN      84.69        NaN      16.51        NaN      12.04
# ..          ...        ...        ...        ...        ...        ...
# 264         NaN        NaN        NaN        NaN        NaN        NaN
# 265         NaN        NaN        NaN        NaN        NaN        NaN
# 266         NaN        NaN        NaN        NaN        NaN        NaN
# 267         NaN        NaN        NaN        NaN        NaN        NaN
# 268         NaN        NaN        NaN        NaN        NaN        NaN
#
#     Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  Unnamed: 13 Unnamed: 14
# 7          NaN    68058.62         NaN           5          NaN           1
# 8          NaN    59374.73         NaN           8          NaN           2
# 9            c    55659.68         NaN           9          NaN           3
# 10         NaN    46945.95         NaN          15          NaN           4
# 11         NaN     60220.8         NaN           5          NaN           6
# ..         ...         ...         ...         ...          ...         ...
# 264        NaN         NaN         NaN         NaN          NaN         NaN
# 265        NaN         NaN         NaN         NaN          NaN         NaN
# 266        NaN         NaN         NaN         NaN          NaN         NaN
# 267        NaN         NaN         NaN         NaN          NaN         NaN
# 268        NaN         NaN         NaN         NaN          NaN         NaN
#
# [262 rows x 15 columns]

# %%
hdi.drop(index=range(0,7),inplace=True)

# %%
hdi.reset_index(drop=True,inplace=True)

# %%
# rename columns
hdi.columns=CurrentHeaders

# %%
hdi.head()
# Out:
#   HDI rank                 Country Human development index (HDI)  NaN  \
# 0        1                  Norway                          0.95  NaN
# 1        2             Switzerland                          0.95  NaN
# 2        3                 Ireland                          0.94  NaN
# 3        4                 Germany                          0.94  NaN
# 4        4  Hong Kong, China (SAR)                          0.94  NaN
#
#   Life expectancy at birth  NaN Expected years of schooling  NaN  \
# 0                    82.27  NaN                       18.06    b
# 1                    83.63  NaN                       16.21  NaN
# 2                     82.1  NaN                       18.79    b
# 3                    81.18  NaN                        17.1  NaN
# 4                    84.69  NaN                       16.51  NaN
#
#   Mean years of schooling  NaN Gross national income (GNI) per capita  NaN  \
# 0                   12.57  NaN                               68058.62  NaN
# 1                   13.38  NaN                               59374.73  NaN
# 2                   12.53    c                               55659.68  NaN
# 3                   14.13  NaN                               46945.95  NaN
# 4                   12.04  NaN                                60220.8  NaN
#
#   GNI per capita rank minus HDI rank  NaN HDI rank
# 0                                  5  NaN        1
# 1                                  8  NaN        2
# 2                                  9  NaN        3
# 3                                 15  NaN        4
# 4                                  5  NaN        6

# %%
hdi.tail(65) #change until you see last data row
# Out:
#     HDI rank                                            Country  \
# 197       ..                                            Somalia
# 198       ..                                             Tuvalu
# 199      NaN                                                NaN
# 200      NaN                           Human development groups
# 201      NaN                        Very high human development
# ..       ...                                                ...
# 257      NaN                          Column 2: UNDESA (2019b).
# 258      NaN  Column 3: UNESCO Institute for Statistics (201...
# 259      NaN  Column 4: UNESCO Institute for Statistics (201...
# 260      NaN  Column 5: World Bank (2019a), IMF (2019) and U...
# 261      NaN  Column 6: Calculated based on data in columns ...
#
#     Human development index (HDI)  NaN Life expectancy at birth  NaN  \
# 197                            ..  NaN                    57.07  NaN
# 198                            ..  NaN                       ..  NaN
# 199                           NaN  NaN                      NaN  NaN
# 200                           NaN  NaN                      NaN  NaN
# 201                          0.89  NaN                    79.51  NaN
# ..                            ...  ...                      ...  ...
# 257                           NaN  NaN                      NaN  NaN
# 258                           NaN  NaN                      NaN  NaN
# 259                           NaN  NaN                      NaN  NaN
# 260                           NaN  NaN                      NaN  NaN
# 261                           NaN  NaN                      NaN  NaN
#
#     Expected years of schooling  NaN Mean years of schooling  NaN  \
# 197                          ..  NaN                      ..  NaN
# 198                       12.31  NaN                      ..  NaN
# 199                         NaN  NaN                     NaN  NaN
# 200                         NaN  NaN                     NaN  NaN
# 201                       16.36  NaN                   12.04  NaN
# ..                          ...  ...                     ...  ...
# 257                         NaN  NaN                     NaN  NaN
# 258                         NaN  NaN                     NaN  NaN
# 259                         NaN  NaN                     NaN  NaN
# 260                         NaN  NaN                     NaN  NaN
# 261                         NaN  NaN                     NaN  NaN
#
#     Gross national income (GNI) per capita  NaN  \
# 197                                     ..  NaN
# 198                                5408.95  NaN
# 199                                    NaN  NaN
# 200                                    NaN  NaN
# 201                               40111.57  NaN
# ..                                     ...  ...
# 257                                    NaN  NaN
# 258                                    NaN  NaN
# 259                                    NaN  NaN
# 260                                    NaN  NaN
# 261                                    NaN  NaN
#
#     GNI per capita rank minus HDI rank  NaN HDI rank
# 197                                 ..  NaN       ..
# 198                                 ..  NaN       ..
# 199                                NaN  NaN      NaN
# 200                                NaN  NaN      NaN
# 201                                  —  NaN        —
# ..                                 ...  ...      ...
# 257                                NaN  NaN      NaN
# 258                                NaN  NaN      NaN
# 259                                NaN  NaN      NaN
# 260                                NaN  NaN      NaN
# 261                                NaN  NaN      NaN
#
# [65 rows x 15 columns]

# %%
# deleting: preview
hdi.drop(index=range(199,262)) # rows starting from 199 will be erased
# Out:
#     HDI rank                 Country Human development index (HDI)  NaN  \
# 0          1                  Norway                          0.95  NaN
# 1          2             Switzerland                          0.95  NaN
# 2          3                 Ireland                          0.94  NaN
# 3          4                 Germany                          0.94  NaN
# 4          4  Hong Kong, China (SAR)                          0.94  NaN
# ..       ...                     ...                           ...  ...
# 194       ..                  Monaco                            ..  NaN
# 195       ..                   Nauru                            ..  NaN
# 196       ..              San Marino                            ..  NaN
# 197       ..                 Somalia                            ..  NaN
# 198       ..                  Tuvalu                            ..  NaN
#
#     Life expectancy at birth  NaN Expected years of schooling  NaN  \
# 0                      82.27  NaN                       18.06    b
# 1                      83.63  NaN                       16.21  NaN
# 2                       82.1  NaN                       18.79    b
# 3                      81.18  NaN                        17.1  NaN
# 4                      84.69  NaN                       16.51  NaN
# ..                       ...  ...                         ...  ...
# 194                       ..  NaN                          ..  NaN
# 195                       ..  NaN                       11.26    e
# 196                       ..  NaN                       15.11  NaN
# 197                    57.07  NaN                          ..  NaN
# 198                       ..  NaN                       12.31  NaN
#
#     Mean years of schooling  NaN Gross national income (GNI) per capita  NaN  \
# 0                     12.57  NaN                               68058.62  NaN
# 1                     13.38  NaN                               59374.73  NaN
# 2                     12.53    c                               55659.68  NaN
# 3                     14.13  NaN                               46945.95  NaN
# 4                     12.04  NaN                                60220.8  NaN
# ..                      ...  ...                                    ...  ...
# 194                      ..  NaN                                     ..  NaN
# 195                      ..  NaN                               17312.59  NaN
# 196                      ..  NaN                                     ..  NaN
# 197                      ..  NaN                                     ..  NaN
# 198                      ..  NaN                                5408.95  NaN
#
#     GNI per capita rank minus HDI rank  NaN HDI rank
# 0                                    5  NaN        1
# 1                                    8  NaN        2
# 2                                    9  NaN        3
# 3                                   15  NaN        4
# 4                                    5  NaN        6
# ..                                 ...  ...      ...
# 194                                 ..  NaN       ..
# 195                                 ..  NaN       ..
# 196                                 ..  NaN       ..
# 197                                 ..  NaN       ..
# 198                                 ..  NaN       ..
#
# [199 rows x 15 columns]

# %%
hdi.drop(index=range(199,262),inplace=True) # should I reset indexes?

# %%
hdi
# Out:
#     HDI rank                 Country Human development index (HDI)  NaN  \
# 0          1                  Norway                          0.95  NaN
# 1          2             Switzerland                          0.95  NaN
# 2          3                 Ireland                          0.94  NaN
# 3          4                 Germany                          0.94  NaN
# 4          4  Hong Kong, China (SAR)                          0.94  NaN
# ..       ...                     ...                           ...  ...
# 194       ..                  Monaco                            ..  NaN
# 195       ..                   Nauru                            ..  NaN
# 196       ..              San Marino                            ..  NaN
# 197       ..                 Somalia                            ..  NaN
# 198       ..                  Tuvalu                            ..  NaN
#
#     Life expectancy at birth  NaN Expected years of schooling  NaN  \
# 0                      82.27  NaN                       18.06    b
# 1                      83.63  NaN                       16.21  NaN
# 2                       82.1  NaN                       18.79    b
# 3                      81.18  NaN                        17.1  NaN
# 4                      84.69  NaN                       16.51  NaN
# ..                       ...  ...                         ...  ...
# 194                       ..  NaN                          ..  NaN
# 195                       ..  NaN                       11.26    e
# 196                       ..  NaN                       15.11  NaN
# 197                    57.07  NaN                          ..  NaN
# 198                       ..  NaN                       12.31  NaN
#
#     Mean years of schooling  NaN Gross national income (GNI) per capita  NaN  \
# 0                     12.57  NaN                               68058.62  NaN
# 1                     13.38  NaN                               59374.73  NaN
# 2                     12.53    c                               55659.68  NaN
# 3                     14.13  NaN                               46945.95  NaN
# 4                     12.04  NaN                                60220.8  NaN
# ..                      ...  ...                                    ...  ...
# 194                      ..  NaN                                     ..  NaN
# 195                      ..  NaN                               17312.59  NaN
# 196                      ..  NaN                                     ..  NaN
# 197                      ..  NaN                                     ..  NaN
# 198                      ..  NaN                                5408.95  NaN
#
#     GNI per capita rank minus HDI rank  NaN HDI rank
# 0                                    5  NaN        1
# 1                                    8  NaN        2
# 2                                    9  NaN        3
# 3                                   15  NaN        4
# 4                                    5  NaN        6
# ..                                 ...  ...      ...
# 194                                 ..  NaN       ..
# 195                                 ..  NaN       ..
# 196                                 ..  NaN       ..
# 197                                 ..  NaN       ..
# 198                                 ..  NaN       ..
#
# [199 rows x 15 columns]

# %%
# Get good columns

GoodHeaders=[header for header in CurrentHeaders if str(header) != 'nan']
#
GoodHeaders
# Out:
# ['HDI rank',
#  'Country',
#  'Human development index (HDI)',
#  'Life expectancy at birth',
#  'Expected years of schooling',
#  'Mean years of schooling',
#  'Gross national income (GNI) per capita',
#  'GNI per capita rank minus HDI rank',
#  'HDI rank']

# %%
FinalHeaders=[header for header in GoodHeaders if 'rank' not in header]
# then
FinalHeaders
# Out:
# ['Country',
#  'Human development index (HDI)',
#  'Life expectancy at birth',
#  'Expected years of schooling',
#  'Mean years of schooling',
#  'Gross national income (GNI) per capita']

# %%
hdi.head()
# Out:
#   HDI rank                 Country Human development index (HDI)  NaN  \
# 0        1                  Norway                          0.95  NaN
# 1        2             Switzerland                          0.95  NaN
# 2        3                 Ireland                          0.94  NaN
# 3        4                 Germany                          0.94  NaN
# 4        4  Hong Kong, China (SAR)                          0.94  NaN
#
#   Life expectancy at birth  NaN Expected years of schooling  NaN  \
# 0                    82.27  NaN                       18.06    b
# 1                    83.63  NaN                       16.21  NaN
# 2                     82.1  NaN                       18.79    b
# 3                    81.18  NaN                        17.1  NaN
# 4                    84.69  NaN                       16.51  NaN
#
#   Mean years of schooling  NaN Gross national income (GNI) per capita  NaN  \
# 0                   12.57  NaN                               68058.62  NaN
# 1                   13.38  NaN                               59374.73  NaN
# 2                   12.53    c                               55659.68  NaN
# 3                   14.13  NaN                               46945.95  NaN
# 4                   12.04  NaN                                60220.8  NaN
#
#   GNI per capita rank minus HDI rank  NaN HDI rank
# 0                                  5  NaN        1
# 1                                  8  NaN        2
# 2                                  9  NaN        3
# 3                                 15  NaN        4
# 4                                  5  NaN        6

# %%
# remember loc works with names, not with positions:

hdi.loc[:,FinalHeaders]
# Out:
#                     Country Human development index (HDI)  \
# 0                    Norway                          0.95
# 1               Switzerland                          0.95
# 2                   Ireland                          0.94
# 3                   Germany                          0.94
# 4    Hong Kong, China (SAR)                          0.94
# ..                      ...                           ...
# 194                  Monaco                            ..
# 195                   Nauru                            ..
# 196              San Marino                            ..
# 197                 Somalia                            ..
# 198                  Tuvalu                            ..
#
#     Life expectancy at birth Expected years of schooling  \
# 0                      82.27                       18.06
# 1                      83.63                       16.21
# 2                       82.1                       18.79
# 3                      81.18                        17.1
# 4                      84.69                       16.51
# ..                       ...                         ...
# 194                       ..                          ..
# 195                       ..                       11.26
# 196                       ..                       15.11
# 197                    57.07                          ..
# 198                       ..                       12.31
#
#     Mean years of schooling Gross national income (GNI) per capita
# 0                     12.57                               68058.62
# 1                     13.38                               59374.73
# 2                     12.53                               55659.68
# 3                     14.13                               46945.95
# 4                     12.04                                60220.8
# ..                      ...                                    ...
# 194                      ..                                     ..
# 195                      ..                               17312.59
# 196                      ..                                     ..
# 197                      ..                                     ..
# 198                      ..                                5408.95
#
# [199 rows x 6 columns]

# %%
hdi=hdi.loc[:,FinalHeaders]

# %%
# you have:
hdi.head()
# Out:
#                   Country Human development index (HDI)  \
# 0                  Norway                          0.95
# 1             Switzerland                          0.95
# 2                 Ireland                          0.94
# 3                 Germany                          0.94
# 4  Hong Kong, China (SAR)                          0.94
#
#   Life expectancy at birth Expected years of schooling  \
# 0                    82.27                       18.06
# 1                    83.63                       16.21
# 2                     82.1                       18.79
# 3                    81.18                        17.1
# 4                    84.69                       16.51
#
#   Mean years of schooling Gross national income (GNI) per capita
# 0                   12.57                               68058.62
# 1                   13.38                               59374.73
# 2                   12.53                               55659.68
# 3                   14.13                               46945.95
# 4                   12.04                                60220.8

# %%
# replace with '' (empty) the "blanks":
hdi.columns.str.replace("\s","")
# Out:
# Index(['Country', 'Humandevelopmentindex(HDI)', 'Lifeexpectancyatbirth',
#        'Expectedyearsofschooling', 'Meanyearsofschooling',
#        'Grossnationalincome(GNI)percapita'],
#       dtype='object')

# %%
# replace with '' (empty) consecutive word characters in parenthesis:
hdi.columns.str.replace("\(\w+\)","")
# Out:
# Index(['Country', 'Human development index ', 'Life expectancy at birth',
#        'Expected years of schooling', 'Mean years of schooling',
#        'Gross national income  per capita'],
#       dtype='object')

# %%
#or all combines
hdi.columns.str.replace("\s+|\(\w+\)","")
# Out:
# Index(['Country', 'Humandevelopmentindex', 'Lifeexpectancyatbirth',
#        'Expectedyearsofschooling', 'Meanyearsofschooling',
#        'Grossnationalincomepercapita'],
#       dtype='object')

# %%
hdi.columns=hdi.columns.str.replace("\s+|\(\w+\)","")

# %%
hdi.head()
# Out:
#                   Country Humandevelopmentindex Lifeexpectancyatbirth  \
# 0                  Norway                  0.95                 82.27
# 1             Switzerland                  0.95                 83.63
# 2                 Ireland                  0.94                  82.1
# 3                 Germany                  0.94                 81.18
# 4  Hong Kong, China (SAR)                  0.94                 84.69
#
#   Expectedyearsofschooling Meanyearsofschooling Grossnationalincomepercapita
# 0                    18.06                12.57                     68058.62
# 1                    16.21                13.38                     59374.73
# 2                    18.79                12.53                     55659.68
# 3                     17.1                14.13                     46945.95
# 4                    16.51                12.04                      60220.8

# %%
# check empty cells from second to last
hdi.iloc[:,1:].isnull().all(axis=1)
# hdi[hdi.iloc[:,1:].isnull().all(axis=1)] #ALL
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 194    False
# 195    False
# 196    False
# 197    False
# 198    False
# Length: 199, dtype: bool

# %%
# the opposite
hdi[hdi.iloc[:,1:].notnull().all(axis=1)]
# Out:
#                     Country Humandevelopmentindex Lifeexpectancyatbirth  \
# 0                    Norway                  0.95                 82.27
# 1               Switzerland                  0.95                 83.63
# 2                   Ireland                  0.94                  82.1
# 3                   Germany                  0.94                 81.18
# 4    Hong Kong, China (SAR)                  0.94                 84.69
# ..                      ...                   ...                   ...
# 194                  Monaco                    ..                    ..
# 195                   Nauru                    ..                    ..
# 196              San Marino                    ..                    ..
# 197                 Somalia                    ..                 57.07
# 198                  Tuvalu                    ..                    ..
#
#     Expectedyearsofschooling Meanyearsofschooling Grossnationalincomepercapita
# 0                      18.06                12.57                     68058.62
# 1                      16.21                13.38                     59374.73
# 2                      18.79                12.53                     55659.68
# 3                       17.1                14.13                     46945.95
# 4                      16.51                12.04                      60220.8
# ..                       ...                  ...                          ...
# 194                       ..                   ..                           ..
# 195                    11.26                   ..                     17312.59
# 196                    15.11                   ..                           ..
# 197                       ..                   ..                           ..
# 198                    12.31                   ..                      5408.95
#
# [195 rows x 6 columns]

# %%
hdi=hdi[hdi.iloc[:,1:].notnull().all(axis=1)]

# %%
hdi.reset_index(drop=True, inplace=True)

# %%
hdi
# Out:
#                     Country Humandevelopmentindex Lifeexpectancyatbirth  \
# 0                    Norway                  0.95                 82.27
# 1               Switzerland                  0.95                 83.63
# 2                   Ireland                  0.94                  82.1
# 3                   Germany                  0.94                 81.18
# 4    Hong Kong, China (SAR)                  0.94                 84.69
# ..                      ...                   ...                   ...
# 190                  Monaco                    ..                    ..
# 191                   Nauru                    ..                    ..
# 192              San Marino                    ..                    ..
# 193                 Somalia                    ..                 57.07
# 194                  Tuvalu                    ..                    ..
#
#     Expectedyearsofschooling Meanyearsofschooling Grossnationalincomepercapita
# 0                      18.06                12.57                     68058.62
# 1                      16.21                13.38                     59374.73
# 2                      18.79                12.53                     55659.68
# 3                       17.1                14.13                     46945.95
# 4                      16.51                12.04                      60220.8
# ..                       ...                  ...                          ...
# 190                       ..                   ..                           ..
# 191                    11.26                   ..                     17312.59
# 192                    15.11                   ..                           ..
# 193                       ..                   ..                           ..
# 194                    12.31                   ..                      5408.95
#
# [195 rows x 6 columns]

# %%
hdi[hdi.iloc[:,1:].isnull().any(axis=1)] #ANY
# Out:
# Empty DataFrame
# Columns: [Country, Humandevelopmentindex, Lifeexpectancyatbirth, Expectedyearsofschooling, Meanyearsofschooling, Grossnationalincomepercapita]
# Index: []

# %%
badHDISymbols=[] # list for bad symbols

NumericColNames=hdi.iloc[:,1:].columns # save names of columns with numeric data

for columnName in NumericColNames:# visit every column name
    for cell in hdi[columnName]:# visit every cell for that column
        try:
            float(cell) # try this
        except: # if not possible:            
            if cell not in badHDISymbols:# if cell is not in the list                
                badHDISymbols.append(cell)# add it to the list

# you get:
badHDISymbols
# Out:
# ['..']

# %%
import numpy as np

hdi.replace(to_replace=badHDISymbols,value=np.nan,inplace=True)

# %%
# you have:
hdi
# Out:
#                     Country Humandevelopmentindex Lifeexpectancyatbirth  \
# 0                    Norway                  0.95                 82.27
# 1               Switzerland                  0.95                 83.63
# 2                   Ireland                  0.94                  82.1
# 3                   Germany                  0.94                 81.18
# 4    Hong Kong, China (SAR)                  0.94                 84.69
# ..                      ...                   ...                   ...
# 190                  Monaco                   NaN                   NaN
# 191                   Nauru                   NaN                   NaN
# 192              San Marino                   NaN                   NaN
# 193                 Somalia                   NaN                 57.07
# 194                  Tuvalu                   NaN                   NaN
#
#     Expectedyearsofschooling Meanyearsofschooling Grossnationalincomepercapita
# 0                      18.06                12.57                     68058.62
# 1                      16.21                13.38                     59374.73
# 2                      18.79                12.53                     55659.68
# 3                       17.1                14.13                     46945.95
# 4                      16.51                12.04                      60220.8
# ..                       ...                  ...                          ...
# 190                      NaN                  NaN                          NaN
# 191                    11.26                  NaN                     17312.59
# 192                    15.11                  NaN                          NaN
# 193                      NaN                  NaN                          NaN
# 194                    12.31                  NaN                      5408.95
#
# [195 rows x 6 columns]

# %%
hdi.describe(include='all')
# Out:
#                  Country Humandevelopmentindex Lifeexpectancyatbirth  \
# count                195                   189                   191
# unique               195                    55                   186
# top     Marshall Islands                  0.76                  76.7
# freq                   1                    10                     2
#
#        Expectedyearsofschooling Meanyearsofschooling  \
# count                       193                  189
# unique                      183                  174
# top                       12.69                 9.67
# freq                          3                    3
#
#        Grossnationalincomepercapita
# count                           191
# unique                          191
# top                          659.73
# freq                              1

# %%
hdi.dtypes
# Out:
# Country                         object
# Humandevelopmentindex           object
# Lifeexpectancyatbirth           object
# Expectedyearsofschooling        object
# Meanyearsofschooling            object
# Grossnationalincomepercapita    object
# dtype: object

# %%
# as easy as:

hdi[NumericColNames]=hdi.loc[:,NumericColNames].apply(pd.to_numeric)

# %%
#recheck
hdi.dtypes
# Out:
# Country                          object
# Humandevelopmentindex           float64
# Lifeexpectancyatbirth           float64
# Expectedyearsofschooling        float64
# Meanyearsofschooling            float64
# Grossnationalincomepercapita    float64
# dtype: object

# %%
# recheck
hdi.describe(include='all')
# Out:
#                  Country  Humandevelopmentindex  Lifeexpectancyatbirth  \
# count                195             189.000000             191.000000
# unique               195                    NaN                    NaN
# top     Marshall Islands                    NaN                    NaN
# freq                   1                    NaN                    NaN
# mean                 NaN               0.713598              72.414660
# std                  NaN               0.150813               7.509694
# min                  NaN               0.380000              52.810000
# 25%                  NaN               0.600000              67.225000
# 50%                  NaN               0.730000              73.750000
# 75%                  NaN               0.830000              77.700000
# max                  NaN               0.950000              84.690000
#
#         Expectedyearsofschooling  Meanyearsofschooling  \
# count                 193.000000            189.000000
# unique                       NaN                   NaN
# top                          NaN                   NaN
# freq                         NaN                   NaN
# mean                   13.212073              8.613228
# std                     2.935116              3.082296
# min                     5.000000              1.590000
# 25%                    11.300000              6.350000
# 50%                    13.070000              9.020000
# 75%                    15.230000             11.290000
# max                    22.100000             14.130000
#
#         Grossnationalincomepercapita
# count                     191.000000
# unique                           NaN
# top                              NaN
# freq                             NaN
# mean                    18368.072461
# std                     19627.352304
# min                       659.730000
# 25%                      4009.435000
# 50%                     11610.910000
# 75%                     26535.420000
# max                    110488.740000

# %%
hdi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 6 columns):
# Country                         195 non-null object
# Humandevelopmentindex           189 non-null float64
# Lifeexpectancyatbirth           191 non-null float64
# Expectedyearsofschooling        193 non-null float64
# Meanyearsofschooling            189 non-null float64
# Grossnationalincomepercapita    191 non-null float64
# dtypes: float64(5), object(1)
# memory usage: 9.3+ KB

# %% [markdown]
# ### Integrating

# %%
cia.columns
# Out:
# Index(['countries', 'co2_in_MT'], dtype='object')

# %%
demodex.columns
# Out:
# Index(['Country', 'Electoralprocessandpluralism', 'Functioningofgovernment',
#        'Politicalparticipation', 'Politicalculture', 'Civilliberties',
#        'Regimetype', 'Continent'],
#       dtype='object')

# %%
hdi.columns
# Out:
# Index(['Country', 'Humandevelopmentindex', 'Lifeexpectancyatbirth',
#        'Expectedyearsofschooling', 'Meanyearsofschooling',
#        'Grossnationalincomepercapita'],
#       dtype='object')

# %%
#hdi and demodex have a common column: Country
hdi.merge(demodex)
# Out:
#                                  Country  Humandevelopmentindex  \
# 0                                 Norway                   0.95
# 1                            Switzerland                   0.95
# 2                                Ireland                   0.94
# 3                                Germany                   0.94
# 4                 Hong Kong, China (SAR)                   0.94
# ..                                   ...                    ...
# 161                              Burundi                   0.42
# 162                                 Chad                   0.40
# 163             Central African Republic                   0.38
# 164                                Niger                   0.38
# 165  Korea (Democratic People's Rep. of)                    NaN
#
#      Lifeexpectancyatbirth  Expectedyearsofschooling  Meanyearsofschooling  \
# 0                    82.27                     18.06                 12.57
# 1                    83.63                     16.21                 13.38
# 2                    82.10                     18.79                 12.53
# 3                    81.18                     17.10                 14.13
# 4                    84.69                     16.51                 12.04
# ..                     ...                       ...                   ...
# 161                  61.25                     11.30                  3.12
# 162                  53.98                      7.47                  2.41
# 163                  52.81                      7.57                  4.28
# 164                  62.02                      6.47                  2.03
# 165                  72.10                     10.84                   NaN
#
#      Grossnationalincomepercapita  Electoralprocessandpluralism  \
# 0                        68058.62                         10.00
# 1                        59374.73                          9.58
# 2                        55659.68                         10.00
# 3                        46945.95                          9.58
# 4                        60220.80                          3.58
# ..                            ...                           ...
# 161                        659.73                          0.00
# 162                       1715.57                          0.00
# 163                        776.68                          1.25
# 164                        912.04                          2.92
# 165                           NaN                          0.00
#
#      Functioningofgovernment  Politicalparticipation  Politicalculture  \
# 0                       9.64                   10.00             10.00
# 1                       9.29                    7.78              9.38
# 2                       7.86                    8.33             10.00
# 3                       8.57                    8.33              7.50
# 4                       4.36                    6.11              7.50
# ..                       ...                     ...               ...
# 161                     0.07                    3.33              5.00
# 162                     0.00                    1.67              3.75
# 163                     0.00                    1.11              1.88
# 164                     1.14                    3.33              4.38
# 165                     2.50                    1.67              1.25
#
#      Civilliberties        Regimetype Continent
# 0              9.71    Full democracy    Europe
# 1              9.12    Full democracy    Europe
# 2             10.00    Full democracy    Europe
# 3              9.41    Full democracy    Europe
# 4              8.53  Flawed democracy      Asia
# ..              ...               ...       ...
# 161            2.35     Authoritarian    Africa
# 162            2.65     Authoritarian    Africa
# 163            2.35     Authoritarian    Africa
# 164            4.71     Authoritarian    Africa
# 165            0.00     Authoritarian      Asia
#
# [166 rows x 13 columns]

# %%
len(hdi), len(demodex)
# Out:
# (0, 167)

# %%
# all hdi and the ones in common with demodex:
hdi.merge(demodex,how='left')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-75-41c95e186b88> in <module>()
#       1 # all hdi and the ones in common with demodex:
# ----> 2 hdi.merge(demodex,how='left')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7347             copy=copy,
#    7348             indicator=indicator,
# -> 7349             validate=validate,
#    7350         )
#    7351
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     617             warnings.warn(msg, UserWarning)
#     618
# --> 619         self._validate_specification()
#     620
#     621         # note this function has side effects
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _validate_specification(self)
#    1188                             ron=self.right_on,
#    1189                             lidx=self.left_index,
# -> 1190                             ridx=self.right_index,
#    1191                         )
#    1192                     )
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False

# %%
hdi.merge(demodex,how='outer',indicator=True) # see last column
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-76-f4dc80585098> in <module>()
# ----> 1 hdi.merge(demodex,how='outer',indicator=True) # see last column
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7347             copy=copy,
#    7348             indicator=indicator,
# -> 7349             validate=validate,
#    7350         )
#    7351
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     617             warnings.warn(msg, UserWarning)
#     618
# --> 619         self._validate_specification()
#     620
#     621         # note this function has side effects
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _validate_specification(self)
#    1188                             ron=self.right_on,
#    1189                             lidx=self.left_index,
# -> 1190                             ridx=self.right_index,
#    1191                         )
#    1192                     )
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False

# %%
dirtyMerge1=hdi.merge(demodex,how='outer',indicator=True)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-77-6669a3cd113c> in <module>()
# ----> 1 dirtyMerge1=hdi.merge(demodex,how='outer',indicator=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7347             copy=copy,
#    7348             indicator=indicator,
# -> 7349             validate=validate,
#    7350         )
#    7351
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     617             warnings.warn(msg, UserWarning)
#     618
# --> 619         self._validate_specification()
#     620
#     621         # note this function has side effects
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _validate_specification(self)
#    1188                             ron=self.right_on,
#    1189                             lidx=self.left_index,
# -> 1190                             ridx=self.right_index,
#    1191                         )
#    1192                     )
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False

# %%
dirtyMerge1.loc[dirtyMerge1['_merge']=='right_only',"Country"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-23fef3d4c2a1> in <module>()
# ----> 1 dirtyMerge1.loc[dirtyMerge1['_merge']=='right_only',"Country"]
#
# NameError: name 'dirtyMerge1' is not defined

# %%
dirtyMerge1.loc[dirtyMerge1['_merge']=='left_only',"Country"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-7f4b69cb8c13> in <module>()
# ----> 1 dirtyMerge1.loc[dirtyMerge1['_merge']=='left_only',"Country"]
#
# NameError: name 'dirtyMerge1' is not defined

# %%
#dictionary of replacements:
replacements1={'South Korea[n 1]': 'Korea (Republic of)', 
              'Cape Verde':'Cabo Verde',
              'Czech Republic':'Czechia',
              'Hong Kong':'Hong Kong, China (SAR)',
              'Moldova':'Moldova (Republic of)',
              'Bolivia':'Bolivia (Plurinational State of)',
              'Tanzania':'Tanzania (United Republic of)',
              'Palestine':'Palestine, State of',
              'Ivory Coast':"Côte d'Ivoire",
              'Republic of the Congo':'Congo',
              'Venezuela':'Venezuela (Bolivarian Republic of)',
              'Vietnam':'Viet Nam',
              'Eswatini':'Eswatini (Kingdom of)',              
              'Russia':'Russian Federation',
              'Iran':'Iran (Islamic Republic of)',
              'Laos':"Lao People's Democratic Republic",
              'Democratic Republic of the Congo':'Congo (Democratic Republic of the)',
              'Syria':'Syrian Arab Republic',
              'North Korea': "Korea (Democratic People's Rep. of)" #check ""
             }

# replacing
demodex.Country.replace(replacements1,inplace=True)

# %%
hdi.merge(demodex)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-81-6a3d9521d8ac> in <module>()
# ----> 1 hdi.merge(demodex)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7347             copy=copy,
#    7348             indicator=indicator,
# -> 7349             validate=validate,
#    7350         )
#    7351
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     617             warnings.warn(msg, UserWarning)
#     618
# --> 619         self._validate_specification()
#     620
#     621         # note this function has side effects
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _validate_specification(self)
#    1188                             ron=self.right_on,
#    1189                             lidx=self.left_index,
# -> 1190                             ridx=self.right_index,
#    1191                         )
#    1192                     )
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False
